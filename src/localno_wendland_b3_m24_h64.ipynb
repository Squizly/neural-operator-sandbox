# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.animation as animation
import xarray as xr

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from neuralop.models.local_no import LocalNO
from neuralop.models import UNO
from neuralop.layers.spectral_convolution import SpectralConv

from tabulate import tabulate

torch.serialization.add_safe_globals([torch.nn.functional.gelu])

# %%
class ContinuousBasisConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, radii=[1, 2, 3], h=1.0, is_differential=False):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.radii = radii
        self.num_bases = len(radii)
        self.h = h
        self.is_differential = is_differential
        
        max_r = max(radii)
        self.padding = (0, max_r, max_r) 

        grid_t, grid_y, grid_x = torch.meshgrid(
            torch.arange(0, 1),
            torch.arange(-max_r, max_r + 1),
            torch.arange(-max_r, max_r + 1),
            indexing='ij'
        )
        self.register_buffer('grid_t', grid_t.float())
        self.register_buffer('grid_y', grid_y.float())
        self.register_buffer('grid_x', grid_x.float())

        self.time_scale = nn.Parameter(torch.tensor(1.0))
        
        self.basis_params = nn.Parameter(torch.tensor(radii, dtype=torch.float32))
        
        fan_in = in_channels * (1 * (2*max_r+1) * (2*max_r+1))
        std = (2.0 / fan_in) ** 0.5
        self.basis_weights = nn.Parameter(torch.randn(out_channels, in_channels, self.num_bases) * std)

    def generate_kernel(self):
        dx = self.grid_x * self.h
        dy = self.grid_y * self.h
        dt = self.grid_t * self.time_scale
        r_sq = dt**2 + dx**2 + dy**2
        r = torch.sqrt(r_sq + 1e-8)
    
        p = torch.clamp(torch.abs(self.basis_params), min=0.1).view(-1, 1, 1, 1)
    
        r_norm = r.unsqueeze(0) / p
        relu_part = F.relu(1.0 - r_norm)
        bases_tensor = (relu_part ** 4) * (4 * r_norm + 1.0)
        
        kernel = torch.einsum('oib, btyx -> oityx', self.basis_weights, bases_tensor)
        kernel = kernel / np.sqrt(self.num_bases)
        
        kernel = kernel * (self.h ** 2)
        
        if self.is_differential:
            kernel_mean = kernel.mean(dim=(2, 3, 4), keepdim=True)
            kernel = kernel - kernel_mean
            
            kernel = kernel / (self.h ** 2 + 1e-8)
            
        return kernel

    def forward(self, x):
        weight = self.generate_kernel()
        
        if weight.shape[2] == 1:
            B, C, T, Y, X = x.shape
            weight_2d = weight.squeeze(2)
            x_2d = x.permute(0, 2, 1, 3, 4).reshape(B * T, C, Y, X)
            pad_y, pad_x = self.padding[1], self.padding[2]
            
            out_2d = F.conv2d(x_2d, weight_2d, bias=None, padding=(pad_y, pad_x))
            out = out_2d.reshape(B, T, self.out_channels, Y, X).permute(0, 2, 1, 3, 4)
            return out
        else:
            return F.conv3d(x, weight, bias=None, padding=self.padding)

# %%
class TrueLocalNOBlock3d(nn.Module):
    def __init__(self, channels, modes, radii=[1, 2, 3]):
        super().__init__()
        self.fno_conv = SpectralConv(in_channels=channels, out_channels=channels, n_modes=modes)
        
        self.local_integral = ContinuousBasisConv3d(
            in_channels=1, out_channels=channels, radii=radii, is_differential=False
        )
        self.local_differential = ContinuousBasisConv3d(
            in_channels=1, out_channels=channels, radii=radii, is_differential=True
        )
        
        self.skip = nn.Conv3d(channels, channels, kernel_size=1)
        self.norm = nn.InstanceNorm3d(channels)
        self.activation = nn.GELU()
        self.fusion_weights = nn.Parameter(torch.ones(4)) 

    def forward(self, x, raw_wells, mask=None):
        identity = x 
        w = torch.softmax(self.fusion_weights, dim=0)
        
        out_fno = self.fno_conv(x)
        out_skip = self.skip(x)
        
        out_int = self.local_integral(raw_wells)
        out_diff = self.local_differential(raw_wells)
        
        out = (w[0] * out_fno + w[1] * out_int + w[2] * out_diff + w[3] * out_skip)
        out = self.norm(identity + out)
        
        if mask is not None:
            out = out * mask
        return self.activation(out)


class CustomLocalNO3d(nn.Module):
    def __init__(self, in_channels=2, out_channels=1, hidden_channels=32, n_layers=4, 
                 modes=(10, 20, 20), radii=[1, 2, 3]):
        super().__init__()
        self.lift = nn.Conv3d(in_channels, hidden_channels, kernel_size=1)
        
        self.blocks = nn.ModuleList([
            TrueLocalNOBlock3d(channels=hidden_channels, modes=modes, radii=radii) 
            for _ in range(n_layers)
        ])
        
        self.project = nn.Sequential(
            nn.Conv3d(hidden_channels, hidden_channels, kernel_size=1),
            nn.GELU(),
            nn.Conv3d(hidden_channels, out_channels, kernel_size=1)
        )

    def forward(self, x, mask=None):
        raw_wells = x[:, 1:2, :, :, :]
        
        x = self.lift(x)
        if mask is not None: x = x * mask
            
        for block in self.blocks:
            x = block(x, raw_wells, mask=mask)
            
        x = self.project(x)
        return x

# %%
CURRENT_DIRECTORY = f'horizontal_correct/'
DATA_PATH = f'data'
ASSETS_PATH = f'assets'
MODELS_PATH = f'models'

filepaths =[f'{DATA_PATH}/source_{i}.hdf5' for i in range(1, 4)]

dim_map = {
    'phony_dim_0' : 'time',
    'phony_dim_1' : 'sample',
    'phony_dim_2' : 'channel',
    'phony_dim_3' : 'Y',
    'phony_dim_4' : 'X'
}

# %%
def preprocess(path):
    print(f'Открытие датасета : {path}')
    ds = xr.open_dataset(path, engine='h5netcdf', phony_dims='sort').rename(dim_map)
    pressure = ds.dataset.isel(channel=0)
    source = ds.source
    return xr.Dataset({'pressure': pressure, 'source':source}, attrs=ds.attrs)

print("Загрузка данных...")
processed_datasets = [preprocess(f) for f in filepaths]
final_ds = xr.concat(processed_datasets, dim='sample').squeeze('phony_dim_5')
# Out:
# Загрузка данных...
# Открытие датасета : data/source_1.hdf5
# Открытие датасета : data/source_2.hdf5
# Открытие датасета : data/source_3.hdf5

# %%
raw_p = final_ds.pressure.values
mask_2d = ~np.isnan(raw_p[0, 0])

p_min, p_max = np.nanmin(raw_p), np.nanmax(raw_p)
norm_p = np.zeros_like(raw_p, dtype='float32')
norm_p[:, :, mask_2d] = (raw_p[:, :, mask_2d] - p_min) / (p_max - p_min)

s_raw = final_ds.source.values.copy()
s_raw[..., ~mask_2d] = 0 
s_abs_max = np.max(np.abs(s_raw))
norm_s = (s_raw / s_abs_max).astype('float32') if s_abs_max != 0 else s_raw

# %%
P_tensor = torch.from_numpy(norm_p).permute(1, 0, 2, 3).float()
S_tensor = torch.from_numpy(norm_s).float()
X_final = torch.stack([P_tensor, S_tensor], dim=2)
STATIC_MASK = torch.from_numpy(mask_2d.astype('float32'))

# %%
def get_indices(size, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    np.random.seed(2318)
    indices = np.arange(size)
    np.random.shuffle(indices)
    train_end = int(size * train_ratio)
    val_end = train_end + int(size * val_ratio)
    return indices[:train_end], indices[train_end:val_end], indices[val_end:]

# %%
class SpatiotemporalDataset(Dataset):
    def __init__(self, data, indices):
        self.data = data[indices] 
        self.N_samples = self.data.shape[0]
        self.T_total = self.data.shape[1]
        self.T_future = self.T_total - 1

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        p_init = self.data[idx, 0, 0] 
        p_init_cube = p_init.unsqueeze(0).repeat(self.T_future, 1, 1)
        s_future_cube = self.data[idx, 1:, 1]
        x = torch.stack([p_init_cube, s_future_cube], dim=0)
        y = self.data[idx, 1:, 0].unsqueeze(0)
        return x, y

# %%
def train_model(modes, 
                hidden_channels, 
                n_layers, 
                train_loader, 
                val_loader, 
                device, 
                static_mask, 
                epochs=200, 
                well_penalty=10.0, 
                radii=[1, 2, 3]
    ):
    
    torch.backends.cudnn.benchmark = True 
    
    model = CustomLocalNO3d(
        in_channels=2, 
        out_channels=1, 
        hidden_channels=hidden_channels, 
        n_layers=n_layers, 
        modes=modes, 
        radii=radii
    ).to(device)

    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-3) 
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)
    
    mask = static_mask.to(device).float()
    mask_3d = mask.unsqueeze(0).unsqueeze(0).unsqueeze(0) 
    
    best_val_l2 = float('inf')
    best_model_path = f"LocalNO__last.pth" 
    patience_counter = 0

    print(f"=== TRAINING | Radii: {radii} ===")

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0.0

        for batch in train_loader:
            x_in, y_true =[b.to(device) for b in batch]
            optimizer.zero_grad()
            
            pred = model(x_in, mask=mask_3d) 
            
            wells_cube = x_in[:, 1:2] 
            well_mask = (torch.abs(wells_cube) > 1e-5).float()
            weight_map = torch.ones_like(pred) + (well_mask * (well_penalty - 1.0))
            
            error = (pred - y_true) * mask_3d
            loss = ((error ** 2) * weight_map).mean()
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            total_train_loss += loss.item() * x_in.size(0)
            
        epoch_train_loss = total_train_loss / len(train_loader.dataset)

        model.eval()
        val_l2_errors =[]
        with torch.no_grad():
            for batch_v in val_loader:
                x_v, y_v =[b.to(device) for b in batch_v]
                pred_v = model(x_v, mask=mask_3d) 
                
                pred_v = pred_v * mask_3d
                true_v = y_v * mask_3d
                
                diff_norm = torch.norm((pred_v - true_v).reshape(x_v.size(0), -1), p=2, dim=1).float()
                true_norm = torch.norm(true_v.reshape(x_v.size(0), -1), p=2, dim=1).float()
                rel_l2 = (diff_norm / torch.clamp(true_norm, min=1e-8)) * 100
                val_l2_errors.extend(rel_l2.cpu().numpy())

        epoch_mean = np.mean(val_l2_errors)
        scheduler.step(epoch_mean) 
        
        current_lr = optimizer.param_groups[0]['lr']
        if epoch_mean < best_val_l2:
            best_val_l2 = epoch_mean
            torch.save(model.state_dict(), best_model_path)
            status = "<--- save"
            patience_counter = 0
        else:
            status = f"[Wait {patience_counter+1}]"
            patience_counter += 1
            
        print(f"Epoch {epoch+1:03d} | LR: {current_lr:.2e} | Train Loss: {epoch_train_loss:.6f} | Val L2: {epoch_mean:.2f}% {status}")

        if patience_counter >= 30:
            print("=== EARLY STOPPING ===")
            break

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    return model

# %%
GPU_ID = "cuda:3"
RADII =[1, 2, 3]
WELL_PENALTY = 10.0

MODES_3D = (10, 24, 24)
HIDDEN_CHANNELS = 64
N_LAYERS = 4
EPOCHS = 150
BATCH_SIZE = 2

device = GPU_ID if torch.cuda.is_available() else "cpu"

train_idx, val_idx, test_idx = get_indices(X_final.shape[0])

train_ds = SpatiotemporalDataset(X_final, train_idx)
val_ds = SpatiotemporalDataset(X_final, val_idx)
test_ds = SpatiotemporalDataset(X_final, test_idx)


train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

best_model = train_model(
    modes=MODES_3D, 
    hidden_channels=HIDDEN_CHANNELS, 
    n_layers=N_LAYERS,
    train_loader=train_loader, 
    val_loader=val_loader,
    static_mask=STATIC_MASK,
    device=device, 
    epochs=EPOCHS,
    well_penalty=WELL_PENALTY,
    radii=RADII
)
# Out:
# === TRAINING | Radii: [1, 2, 3] ===
# Epoch 001 | LR: 5.00e-04 | Train Loss: 0.009812 | Val L2: 26.52% <--- save
# Epoch 002 | LR: 5.00e-04 | Train Loss: 0.005902 | Val L2: 23.75% <--- save
# Epoch 003 | LR: 5.00e-04 | Train Loss: 0.004803 | Val L2: 21.72% <--- save
# Epoch 004 | LR: 5.00e-04 | Train Loss: 0.003954 | Val L2: 20.61% <--- save
# Epoch 005 | LR: 5.00e-04 | Train Loss: 0.003266 | Val L2: 17.36% <--- save
# Epoch 006 | LR: 5.00e-04 | Train Loss: 0.002608 | Val L2: 15.61% <--- save
# Epoch 007 | LR: 5.00e-04 | Train Loss: 0.002141 | Val L2: 15.25% <--- save
# Epoch 008 | LR: 5.00e-04 | Train Loss: 0.001770 | Val L2: 14.35% <--- save
# Epoch 009 | LR: 5.00e-04 | Train Loss: 0.001571 | Val L2: 12.80% <--- save
# Epoch 010 | LR: 5.00e-04 | Train Loss: 0.001368 | Val L2: 12.51% <--- save
# Epoch 011 | LR: 5.00e-04 | Train Loss: 0.001229 | Val L2: 12.44% <--- save
# Epoch 012 | LR: 5.00e-04 | Train Loss: 0.001089 | Val L2: 11.40% <--- save
# Epoch 013 | LR: 5.00e-04 | Train Loss: 0.001023 | Val L2: 11.28% <--- save
# Epoch 014 | LR: 5.00e-04 | Train Loss: 0.000933 | Val L2: 11.05% <--- save
# Epoch 015 | LR: 5.00e-04 | Train Loss: 0.000881 | Val L2: 11.25% [Wait 1]
# Epoch 016 | LR: 5.00e-04 | Train Loss: 0.000808 | Val L2: 10.59% <--- save
# Epoch 017 | LR: 5.00e-04 | Train Loss: 0.000739 | Val L2: 11.84% [Wait 1]
# Epoch 018 | LR: 5.00e-04 | Train Loss: 0.000697 | Val L2: 10.55% <--- save
# Epoch 019 | LR: 5.00e-04 | Train Loss: 0.000657 | Val L2: 10.84% [Wait 1]
# Epoch 020 | LR: 5.00e-04 | Train Loss: 0.000628 | Val L2: 11.06% [Wait 2]
# Epoch 021 | LR: 5.00e-04 | Train Loss: 0.000584 | Val L2: 10.20% <--- save
# Epoch 022 | LR: 5.00e-04 | Train Loss: 0.000567 | Val L2: 9.85% <--- save
# Epoch 023 | LR: 5.00e-04 | Train Loss: 0.000529 | Val L2: 10.11% [Wait 1]
# Epoch 024 | LR: 5.00e-04 | Train Loss: 0.000496 | Val L2: 9.96% [Wait 2]
# Epoch 025 | LR: 5.00e-04 | Train Loss: 0.000485 | Val L2: 9.79% <--- save
# Epoch 026 | LR: 5.00e-04 | Train Loss: 0.000463 | Val L2: 9.97% [Wait 1]
# Epoch 027 | LR: 5.00e-04 | Train Loss: 0.000447 | Val L2: 9.55% <--- save
# Epoch 028 | LR: 5.00e-04 | Train Loss: 0.000427 | Val L2: 9.66% [Wait 1]
# Epoch 029 | LR: 5.00e-04 | Train Loss: 0.000411 | Val L2: 9.49% <--- save
# Epoch 030 | LR: 5.00e-04 | Train Loss: 0.000402 | Val L2: 9.52% [Wait 1]
# Epoch 031 | LR: 5.00e-04 | Train Loss: 0.000385 | Val L2: 9.50% [Wait 2]
# Epoch 032 | LR: 5.00e-04 | Train Loss: 0.000369 | Val L2: 9.35% <--- save
# Epoch 033 | LR: 5.00e-04 | Train Loss: 0.000363 | Val L2: 9.52% [Wait 1]
# Epoch 034 | LR: 5.00e-04 | Train Loss: 0.000344 | Val L2: 9.24% <--- save
# Epoch 035 | LR: 5.00e-04 | Train Loss: 0.000339 | Val L2: 9.32% [Wait 1]
# Epoch 036 | LR: 5.00e-04 | Train Loss: 0.000323 | Val L2: 9.30% [Wait 2]
# Epoch 037 | LR: 5.00e-04 | Train Loss: 0.000311 | Val L2: 9.39% [Wait 3]
# Epoch 038 | LR: 5.00e-04 | Train Loss: 0.000309 | Val L2: 9.39% [Wait 4]
# Epoch 039 | LR: 5.00e-04 | Train Loss: 0.000304 | Val L2: 9.17% <--- save
# Epoch 040 | LR: 5.00e-04 | Train Loss: 0.000291 | Val L2: 9.33% [Wait 1]
# Epoch 041 | LR: 5.00e-04 | Train Loss: 0.000279 | Val L2: 9.21% [Wait 2]
# Epoch 042 | LR: 5.00e-04 | Train Loss: 0.000277 | Val L2: 9.18% [Wait 3]
# Epoch 043 | LR: 5.00e-04 | Train Loss: 0.000269 | Val L2: 9.07% <--- save
# Epoch 044 | LR: 5.00e-04 | Train Loss: 0.000262 | Val L2: 9.00% <--- save
# Epoch 045 | LR: 5.00e-04 | Train Loss: 0.000256 | Val L2: 9.29% [Wait 1]
# Epoch 046 | LR: 5.00e-04 | Train Loss: 0.000251 | Val L2: 8.99% <--- save
# Epoch 047 | LR: 5.00e-04 | Train Loss: 0.000246 | Val L2: 9.11% [Wait 1]
# Epoch 048 | LR: 5.00e-04 | Train Loss: 0.000239 | Val L2: 9.30% [Wait 2]
# Epoch 049 | LR: 5.00e-04 | Train Loss: 0.000234 | Val L2: 9.01% [Wait 3]
# Epoch 050 | LR: 5.00e-04 | Train Loss: 0.000233 | Val L2: 9.02% [Wait 4]
# Epoch 051 | LR: 5.00e-04 | Train Loss: 0.000233 | Val L2: 9.07% [Wait 5]
# Epoch 052 | LR: 5.00e-04 | Train Loss: 0.000215 | Val L2: 9.34% [Wait 6]
# Epoch 053 | LR: 5.00e-04 | Train Loss: 0.000215 | Val L2: 9.09% [Wait 7]
# Epoch 054 | LR: 5.00e-04 | Train Loss: 0.000212 | Val L2: 8.98% <--- save
# Epoch 055 | LR: 5.00e-04 | Train Loss: 0.000207 | Val L2: 8.88% <--- save
# Epoch 056 | LR: 5.00e-04 | Train Loss: 0.000208 | Val L2: 8.89% [Wait 1]
# Epoch 057 | LR: 5.00e-04 | Train Loss: 0.000205 | Val L2: 8.97% [Wait 2]
# Epoch 058 | LR: 5.00e-04 | Train Loss: 0.000197 | Val L2: 8.73% <--- save
# Epoch 059 | LR: 5.00e-04 | Train Loss: 0.000190 | Val L2: 8.89% [Wait 1]
# Epoch 060 | LR: 5.00e-04 | Train Loss: 0.000189 | Val L2: 9.06% [Wait 2]
# Epoch 061 | LR: 5.00e-04 | Train Loss: 0.000186 | Val L2: 8.74% [Wait 3]
# Epoch 062 | LR: 5.00e-04 | Train Loss: 0.000185 | Val L2: 8.82% [Wait 4]
# Epoch 063 | LR: 5.00e-04 | Train Loss: 0.000181 | Val L2: 8.74% [Wait 5]
# Epoch 064 | LR: 5.00e-04 | Train Loss: 0.000181 | Val L2: 8.82% [Wait 6]
# Epoch 065 | LR: 5.00e-04 | Train Loss: 0.000172 | Val L2: 8.92% [Wait 7]
# Epoch 066 | LR: 5.00e-04 | Train Loss: 0.000178 | Val L2: 8.76% [Wait 8]
# Epoch 067 | LR: 5.00e-04 | Train Loss: 0.000174 | Val L2: 8.70% <--- save
# Epoch 068 | LR: 5.00e-04 | Train Loss: 0.000171 | Val L2: 8.76% [Wait 1]
# Epoch 069 | LR: 5.00e-04 | Train Loss: 0.000166 | Val L2: 8.75% [Wait 2]
# Epoch 070 | LR: 5.00e-04 | Train Loss: 0.000168 | Val L2: 8.76% [Wait 3]
# Epoch 071 | LR: 5.00e-04 | Train Loss: 0.000167 | Val L2: 8.75% [Wait 4]
# Epoch 072 | LR: 5.00e-04 | Train Loss: 0.000159 | Val L2: 8.83% [Wait 5]
# Epoch 073 | LR: 5.00e-04 | Train Loss: 0.000156 | Val L2: 8.83% [Wait 6]
# Epoch 074 | LR: 5.00e-04 | Train Loss: 0.000157 | Val L2: 8.77% [Wait 7]
# Epoch 075 | LR: 5.00e-04 | Train Loss: 0.000157 | Val L2: 8.66% <--- save
# Epoch 076 | LR: 5.00e-04 | Train Loss: 0.000147 | Val L2: 8.78% [Wait 1]
# Epoch 077 | LR: 5.00e-04 | Train Loss: 0.000148 | Val L2: 8.70% [Wait 2]
# Epoch 078 | LR: 5.00e-04 | Train Loss: 0.000151 | Val L2: 8.71% [Wait 3]
# Epoch 079 | LR: 5.00e-04 | Train Loss: 0.000148 | Val L2: 8.65% <--- save
# Epoch 080 | LR: 5.00e-04 | Train Loss: 0.000148 | Val L2: 8.65% <--- save
# Epoch 081 | LR: 5.00e-04 | Train Loss: 0.000143 | Val L2: 8.67% [Wait 1]
# Epoch 082 | LR: 5.00e-04 | Train Loss: 0.000141 | Val L2: 8.71% [Wait 2]
# Epoch 083 | LR: 5.00e-04 | Train Loss: 0.000147 | Val L2: 8.67% [Wait 3]
# Epoch 084 | LR: 5.00e-04 | Train Loss: 0.000137 | Val L2: 8.66% [Wait 4]
# Epoch 085 | LR: 5.00e-04 | Train Loss: 0.000140 | Val L2: 8.55% <--- save
# Epoch 086 | LR: 5.00e-04 | Train Loss: 0.000138 | Val L2: 8.70% [Wait 1]
# Epoch 087 | LR: 5.00e-04 | Train Loss: 0.000136 | Val L2: 8.68% [Wait 2]
# Epoch 088 | LR: 5.00e-04 | Train Loss: 0.000135 | Val L2: 8.65% [Wait 3]
# Epoch 089 | LR: 5.00e-04 | Train Loss: 0.000137 | Val L2: 8.75% [Wait 4]
# Epoch 090 | LR: 5.00e-04 | Train Loss: 0.000132 | Val L2: 8.60% [Wait 5]
# Epoch 091 | LR: 5.00e-04 | Train Loss: 0.000128 | Val L2: 8.56% [Wait 6]
# Epoch 092 | LR: 5.00e-04 | Train Loss: 0.000128 | Val L2: 8.71% [Wait 7]
# Epoch 093 | LR: 5.00e-04 | Train Loss: 0.000131 | Val L2: 8.60% [Wait 8]
# Epoch 094 | LR: 5.00e-04 | Train Loss: 0.000130 | Val L2: 8.53% <--- save
# Epoch 095 | LR: 5.00e-04 | Train Loss: 0.000126 | Val L2: 8.56% [Wait 1]
# Epoch 096 | LR: 5.00e-04 | Train Loss: 0.000123 | Val L2: 8.60% [Wait 2]
# Epoch 097 | LR: 5.00e-04 | Train Loss: 0.000128 | Val L2: 8.55% [Wait 3]
# Epoch 098 | LR: 5.00e-04 | Train Loss: 0.000126 | Val L2: 8.60% [Wait 4]
# Epoch 099 | LR: 5.00e-04 | Train Loss: 0.000123 | Val L2: 8.63% [Wait 5]
# Epoch 100 | LR: 5.00e-04 | Train Loss: 0.000121 | Val L2: 8.60% [Wait 6]
# Epoch 101 | LR: 5.00e-04 | Train Loss: 0.000122 | Val L2: 8.75% [Wait 7]
# Epoch 102 | LR: 5.00e-04 | Train Loss: 0.000119 | Val L2: 8.70% [Wait 8]
# Epoch 103 | LR: 5.00e-04 | Train Loss: 0.000121 | Val L2: 8.54% [Wait 9]
# Epoch 104 | LR: 5.00e-04 | Train Loss: 0.000113 | Val L2: 8.57% [Wait 10]
# Epoch 105 | LR: 5.00e-04 | Train Loss: 0.000119 | Val L2: 8.61% [Wait 11]
# Epoch 106 | LR: 5.00e-04 | Train Loss: 0.000112 | Val L2: 8.48% <--- save
# Epoch 107 | LR: 5.00e-04 | Train Loss: 0.000113 | Val L2: 8.77% [Wait 1]
# Epoch 108 | LR: 5.00e-04 | Train Loss: 0.000114 | Val L2: 8.54% [Wait 2]
# Epoch 109 | LR: 5.00e-04 | Train Loss: 0.000113 | Val L2: 8.48% [Wait 3]
# Epoch 110 | LR: 5.00e-04 | Train Loss: 0.000116 | Val L2: 8.54% [Wait 4]
# Epoch 111 | LR: 5.00e-04 | Train Loss: 0.000117 | Val L2: 8.58% [Wait 5]
# Epoch 112 | LR: 5.00e-04 | Train Loss: 0.000111 | Val L2: 8.55% [Wait 6]
# Epoch 113 | LR: 5.00e-04 | Train Loss: 0.000108 | Val L2: 8.68% [Wait 7]
# Epoch 114 | LR: 5.00e-04 | Train Loss: 0.000109 | Val L2: 8.59% [Wait 8]
# Epoch 115 | LR: 5.00e-04 | Train Loss: 0.000110 | Val L2: 8.54% [Wait 9]
# Epoch 116 | LR: 5.00e-04 | Train Loss: 0.000112 | Val L2: 8.63% [Wait 10]
# Epoch 117 | LR: 5.00e-04 | Train Loss: 0.000106 | Val L2: 8.60% [Wait 11]
# Epoch 118 | LR: 5.00e-04 | Train Loss: 0.000104 | Val L2: 8.56% [Wait 12]
# Epoch 119 | LR: 5.00e-04 | Train Loss: 0.000104 | Val L2: 8.53% [Wait 13]
# Epoch 120 | LR: 5.00e-04 | Train Loss: 0.000102 | Val L2: 8.55% [Wait 14]
# Epoch 121 | LR: 5.00e-04 | Train Loss: 0.000108 | Val L2: 8.52% [Wait 15]
# Epoch 122 | LR: 2.50e-04 | Train Loss: 0.000104 | Val L2: 8.56% [Wait 16]
# Epoch 123 | LR: 2.50e-04 | Train Loss: 0.000084 | Val L2: 8.42% <--- save
# Epoch 124 | LR: 2.50e-04 | Train Loss: 0.000071 | Val L2: 8.41% <--- save
# Epoch 125 | LR: 2.50e-04 | Train Loss: 0.000068 | Val L2: 8.41% <--- save
# Epoch 126 | LR: 2.50e-04 | Train Loss: 0.000068 | Val L2: 8.41% <--- save
# Epoch 127 | LR: 2.50e-04 | Train Loss: 0.000069 | Val L2: 8.41% [Wait 1]
# Epoch 128 | LR: 2.50e-04 | Train Loss: 0.000069 | Val L2: 8.45% [Wait 2]
# Epoch 129 | LR: 2.50e-04 | Train Loss: 0.000069 | Val L2: 8.41% [Wait 3]
# Epoch 130 | LR: 2.50e-04 | Train Loss: 0.000069 | Val L2: 8.43% [Wait 4]
# Epoch 131 | LR: 2.50e-04 | Train Loss: 0.000067 | Val L2: 8.42% [Wait 5]
# Epoch 132 | LR: 2.50e-04 | Train Loss: 0.000067 | Val L2: 8.40% <--- save
