# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.animation as animation
import xarray as xr

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from neuralop.models import UNO

torch.serialization.add_safe_globals([torch.nn.functional.gelu])

# %%
CURRENT_DIRECTORY = f'horizontal_correct/'
DATA_PATH = f'data'
ASSETS_PATH = f'assets'
MODELS_PATH = f'models'

filepaths = [f'{DATA_PATH}/source_{i}.hdf5' for i in range(1, 4)]

dim_map = {
    'phony_dim_0' : 'time',
    'phony_dim_1' : 'sample',
    'phony_dim_2' : 'channel',
    'phony_dim_3' : 'Y',
    'phony_dim_4' : 'X'
}

# %%
def preprocess(path):
    print(f'Открытие датасета : {path}')
    ds = xr.open_dataset(path, engine='h5netcdf', phony_dims='sort').rename(dim_map)
    pressure = ds.dataset.isel(channel=0)
    source = ds.source
    return xr.Dataset({'pressure': pressure, 'source':source}, attrs=ds.attrs)

print("Загрузка данных...")
processed_datasets = [preprocess(f) for f in filepaths]
final_ds = xr.concat(processed_datasets, dim='sample').squeeze('phony_dim_5')
# Out:
# Загрузка данных...
# Открытие датасета : data/source_1.hdf5
# Открытие датасета : data/source_2.hdf5
# Открытие датасета : data/source_3.hdf5

# %%
raw_p = final_ds.pressure.values
mask_2d = ~np.isnan(raw_p[0, 0])

p_min, p_max = np.nanmin(raw_p), np.nanmax(raw_p)
norm_p = np.zeros_like(raw_p, dtype='float32')
norm_p[:, :, mask_2d] = (raw_p[:, :, mask_2d] - p_min) / (p_max - p_min)

s_raw = final_ds.source.values.copy()
s_raw[..., ~mask_2d] = 0 
s_abs_max = np.max(np.abs(s_raw))
norm_s = (s_raw / s_abs_max).astype('float32') if s_abs_max != 0 else s_raw

# %%
P_tensor = torch.from_numpy(norm_p).permute(1, 0, 2, 3).float()
S_tensor = torch.from_numpy(norm_s).float()
X_final = torch.stack([P_tensor, S_tensor], dim=2)
STATIC_MASK = torch.from_numpy(mask_2d.astype('float32'))

# %%
def get_indices(size, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    np.random.seed(2318)
    indices = np.arange(size)
    np.random.shuffle(indices)
    train_end = int(size * train_ratio)
    val_end = train_end + int(size * val_ratio)
    return indices[:train_end], indices[train_end:val_end], indices[val_end:]

# %%
class SpatiotemporalDataset(Dataset):
    def __init__(self, data, indices):
        self.data = data[indices] 
        self.N_samples = self.data.shape[0]
        self.T_total = self.data.shape[1]
        self.T_future = self.T_total - 1

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        p_init = self.data[idx, 0, 0] 
        p_init_cube = p_init.unsqueeze(0).repeat(self.T_future, 1, 1)
        
        s_future_cube = self.data[idx, 1:, 1]
        
        x = torch.stack([p_init_cube, s_future_cube], dim=0)
        
        y = self.data[idx, 1:, 0].unsqueeze(0)
        
        return x, y

# %%
class HybridUNO(nn.Module):
    def __init__(self, base_uno):
        super().__init__()
        self.uno = base_uno
        
        self.local_branch = nn.Sequential(
            nn.Conv3d(in_channels=2, out_channels=16, kernel_size=3, padding=1),
            nn.GELU(),
            nn.Conv3d(in_channels=16, out_channels=16, kernel_size=3, padding=1),
            nn.GELU(),
            nn.Conv3d(in_channels=16, out_channels=1, kernel_size=3, padding=1)
        )

    def forward(self, x):
        global_pred = self.uno(x)
        local_pred = self.local_branch(x)
        
        return global_pred + local_pred

# %%
def train_model(modes, scalings, out_channels, train_loader, val_loader, device, static_mask, epochs=250):
    
    base_model = UNO(
        in_channels=2, 
        out_channels=1,
        domain_padding=0.1,
        non_linearity=torch.nn.functional.gelu,
        hidden_channels=64, 
        n_layers=4,
        projection_channels=64,
        uno_out_channels=out_channels,
        uno_n_modes=modes,
        uno_scalings=scalings,
        channel_mlp_skip="linear"
    )
    model = HybridUNO(base_model).to(device)

    criterion = nn.MSELoss()
    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-3) 
    
    mask = static_mask.to(device).float()
    mask_3d = mask.unsqueeze(0).unsqueeze(0).unsqueeze(0) 

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)
    
    best_val_l2 = float('inf')
    best_model_path = "uno3d_ver2_best.pth"
    patience_counter = 0

    train_losses, val_losses_mean = [], []
    print(f"=== START 3D TRAINING | Device: {device} ===")

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0.0

        for batch in train_loader:
            x_in, y_true = [b.to(device) for b in batch]
            optimizer.zero_grad()
            
            pred = model(x_in) 
            
            loss = criterion(pred * mask_3d, y_true * mask_3d)
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            total_train_loss += loss.item() * x_in.size(0)
            
        epoch_train_loss = total_train_loss / len(train_loader.dataset)

        model.eval()
        val_l2_errors = []
        with torch.no_grad():
            for batch_v in val_loader:
                x_v, y_v = [b.to(device) for b in batch_v]
                pred_v = model(x_v) * mask_3d
                true_v = y_v * mask_3d
                
                preds_flat = pred_v.reshape(x_v.size(0), -1)
                trues_flat = true_v.reshape(x_v.size(0), -1)

                diff_norm = torch.norm(preds_flat - trues_flat, p=2, dim=1)
                true_norm = torch.norm(trues_flat, p=2, dim=1)
                
                rel_l2 = (diff_norm / torch.clamp(true_norm, min=1e-8)) * 100
                val_l2_errors.extend(rel_l2.cpu().numpy())

        epoch_mean = np.mean(val_l2_errors)
        scheduler.step(epoch_mean) 
        
        current_lr = optimizer.param_groups[0]['lr']
        if epoch_mean < best_val_l2:
            best_val_l2 = epoch_mean
            torch.save(model.state_dict(), best_model_path)
            status = "<--- save"
            patience_counter = 0
        else:
            status = f"[Wait {patience_counter+1}]"
            patience_counter += 1
            
        print(f"Epoch {epoch+1:03d} | LR: {current_lr:.2e} | Train Loss: {epoch_train_loss:.6f} | Val L2: {epoch_mean:.2f}% {status}")

        if patience_counter >= 30:
            print("=== EARLY STOPPING ===")
            break

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    return model

# %%
def analyze_results(model, test_loader, device, static_mask, num_plots=5):
    model.eval()
    mask_3d = static_mask.to(device).float().unsqueeze(0).unsqueeze(0).unsqueeze(0)
    
    global_errors = []
    well_errors = []
    plots_done = 0

    print("\n=== АНАЛИЗ РЕЗУЛЬТАТОВ НА ТЕСТЕ ===")
    with torch.no_grad():
        for batch in test_loader:
            x_in, y_true = [b.to(device) for b in batch]
            pred = model(x_in) * mask_3d
            true = y_true * mask_3d
            
            wells_cube = x_in[:, 1:2] 
            well_mask = (torch.abs(wells_cube) > 1e-5).float() * mask_3d
            
            for i in range(x_in.shape[0]):
                p_p = pred[i]
                p_t = true[i]
                w_m = well_mask[i]
                
                g_err = (torch.norm(p_p - p_t) / torch.norm(p_t)) * 100
                global_errors.append(g_err.item())
                
                if w_m.sum() > 0:
                    w_err = (torch.norm((p_p - p_t)*w_m) / torch.norm(p_t*w_m)) * 100
                    well_errors.append(w_err.item())

                if plots_done < num_plots:
                    t_mid = p_t.shape[1] // 2
                    
                    true_np = p_t[0, t_mid].cpu().numpy()
                    pred_np = p_p[0, t_mid].cpu().numpy()
                    wells_np = wells_cube[i, 0, t_mid].cpu().numpy()
                    
                    fig, axes = plt.subplots(1, 4, figsize=(20, 4))

                    axes[0].imshow(wells_np, cmap='bwr')
                    axes[0].set_title(f"Скважины (t={t_mid})")

                    axes[1].imshow(true_np, cmap='viridis')
                    axes[1].set_title(f"Истинное давление (t={t_mid})")

                    axes[2].imshow(pred_np, cmap='viridis')
                    axes[2].set_title(f"Предсказание (t={t_mid})")

                    epsilon = 1e-5
                    
                    rel_err_map = (np.abs(true_np - pred_np) / (np.abs(true_np) + epsilon)) * 100
                    
                    rel_err_map = np.clip(rel_err_map, 0, 100)
                    
                    im = axes[3].imshow(rel_err_map, cmap='magma', vmin=0, vmax=100)
                    axes[3].set_title("Процентная ошибка (%)")
                    fig.colorbar(im, ax=axes[3])
                    
                    plt.tight_layout()
                    plt.show()
                    
                    plots_done += 1
                    
                    if plots_done >= num_plots:
                        break
            
    print(f"Средняя глобальная ошибка на тесте: {np.mean(global_errors):.2f}%")
    print(f"Средняя ошибка В СКВАЖИНАХ на тесте: {np.mean(well_errors):.2f}%")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

train_idx, val_idx, test_idx = get_indices(X_final.shape[0])

train_ds = SpatiotemporalDataset(X_final, train_idx)
val_ds = SpatiotemporalDataset(X_final, val_idx)
test_ds = SpatiotemporalDataset(X_final, test_idx)

BATCH_SIZE = 4

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

MODES_3D = [
    [12, 24, 24], 
    [12, 16, 16], 
    [12, 16, 16], 
    [12, 24, 24]
]

SCALINGS_3D = [
    [1.0, 0.5, 0.5], 
    [1.0, 0.5, 0.5], 
    [1.0, 2.0, 2.0], 
    [1.0, 2.0, 2.0]
]

OUT_CHANNELS_3D = [64, 128, 128, 64] 

EPOCHS = 150

best_model = train_model(
    MODES_3D, SCALINGS_3D, OUT_CHANNELS_3D,
    train_loader, val_loader,
    static_mask=STATIC_MASK,
    device=device, epochs=EPOCHS
)

analyze_results(best_model, test_loader, device, STATIC_MASK, num_plots=5)
# Out:
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# === START 3D TRAINING | Device: cuda:0 ===
# Epoch 001 | LR: 5.00e-04 | Train Loss: 0.011192 | Val L2: 27.80% <--- save
# Epoch 002 | LR: 5.00e-04 | Train Loss: 0.005104 | Val L2: 21.27% <--- save
# Epoch 003 | LR: 5.00e-04 | Train Loss: 0.003217 | Val L2: 16.31% <--- save
# Epoch 004 | LR: 5.00e-04 | Train Loss: 0.001974 | Val L2: 16.49% [Wait 1]
# Epoch 005 | LR: 5.00e-04 | Train Loss: 0.001571 | Val L2: 13.23% <--- save
# Epoch 006 | LR: 5.00e-04 | Train Loss: 0.001325 | Val L2: 12.16% <--- save
# Epoch 007 | LR: 5.00e-04 | Train Loss: 0.001146 | Val L2: 11.85% <--- save
# Epoch 008 | LR: 5.00e-04 | Train Loss: 0.001017 | Val L2: 12.80% [Wait 1]
# Epoch 009 | LR: 5.00e-04 | Train Loss: 0.000897 | Val L2: 11.94% [Wait 2]
# Epoch 010 | LR: 5.00e-04 | Train Loss: 0.000819 | Val L2: 11.67% <--- save
# Epoch 011 | LR: 5.00e-04 | Train Loss: 0.000752 | Val L2: 10.47% <--- save
# Epoch 012 | LR: 5.00e-04 | Train Loss: 0.000708 | Val L2: 10.40% <--- save
# Epoch 013 | LR: 5.00e-04 | Train Loss: 0.000648 | Val L2: 10.27% <--- save
# Epoch 014 | LR: 5.00e-04 | Train Loss: 0.000600 | Val L2: 9.65% <--- save
# Epoch 015 | LR: 5.00e-04 | Train Loss: 0.000574 | Val L2: 10.04% [Wait 1]
# Epoch 016 | LR: 5.00e-04 | Train Loss: 0.000524 | Val L2: 9.47% <--- save
# Epoch 017 | LR: 5.00e-04 | Train Loss: 0.000484 | Val L2: 9.35% <--- save
# Epoch 018 | LR: 5.00e-04 | Train Loss: 0.000462 | Val L2: 9.67% [Wait 1]
# Epoch 019 | LR: 5.00e-04 | Train Loss: 0.000442 | Val L2: 9.41% [Wait 2]
# Epoch 020 | LR: 5.00e-04 | Train Loss: 0.000414 | Val L2: 9.46% [Wait 3]
# Epoch 021 | LR: 5.00e-04 | Train Loss: 0.000391 | Val L2: 9.16% <--- save
# Epoch 022 | LR: 5.00e-04 | Train Loss: 0.000367 | Val L2: 9.12% <--- save
# Epoch 023 | LR: 5.00e-04 | Train Loss: 0.000354 | Val L2: 8.91% <--- save
# Epoch 024 | LR: 5.00e-04 | Train Loss: 0.000350 | Val L2: 8.99% [Wait 1]
# Epoch 025 | LR: 5.00e-04 | Train Loss: 0.000325 | Val L2: 9.16% [Wait 2]
# Epoch 026 | LR: 5.00e-04 | Train Loss: 0.000307 | Val L2: 8.66% <--- save
# Epoch 027 | LR: 5.00e-04 | Train Loss: 0.000280 | Val L2: 8.90% [Wait 1]
# Epoch 028 | LR: 5.00e-04 | Train Loss: 0.000286 | Val L2: 8.89% [Wait 2]
# Epoch 029 | LR: 5.00e-04 | Train Loss: 0.000271 | Val L2: 8.62% <--- save
# Epoch 030 | LR: 5.00e-04 | Train Loss: 0.000248 | Val L2: 8.60% <--- save
# Epoch 031 | LR: 5.00e-04 | Train Loss: 0.000246 | Val L2: 8.68% [Wait 1]
# Epoch 032 | LR: 5.00e-04 | Train Loss: 0.000238 | Val L2: 8.74% [Wait 2]
# Epoch 033 | LR: 5.00e-04 | Train Loss: 0.000232 | Val L2: 9.05% [Wait 3]
# Epoch 034 | LR: 5.00e-04 | Train Loss: 0.000242 | Val L2: 8.64% [Wait 4]
# Epoch 035 | LR: 5.00e-04 | Train Loss: 0.000224 | Val L2: 8.42% <--- save
# Epoch 036 | LR: 5.00e-04 | Train Loss: 0.000211 | Val L2: 8.54% [Wait 1]
# Epoch 037 | LR: 5.00e-04 | Train Loss: 0.000205 | Val L2: 8.49% [Wait 2]
# Epoch 038 | LR: 5.00e-04 | Train Loss: 0.000195 | Val L2: 8.53% [Wait 3]
# Epoch 039 | LR: 5.00e-04 | Train Loss: 0.000193 | Val L2: 8.49% [Wait 4]
# Epoch 040 | LR: 5.00e-04 | Train Loss: 0.000202 | Val L2: 8.47% [Wait 5]
# Epoch 041 | LR: 5.00e-04 | Train Loss: 0.000189 | Val L2: 8.38% <--- save
# Epoch 042 | LR: 5.00e-04 | Train Loss: 0.000185 | Val L2: 8.55% [Wait 1]
# Epoch 043 | LR: 5.00e-04 | Train Loss: 0.000180 | Val L2: 8.29% <--- save
# Epoch 044 | LR: 5.00e-04 | Train Loss: 0.000175 | Val L2: 8.43% [Wait 1]
# Epoch 045 | LR: 5.00e-04 | Train Loss: 0.000170 | Val L2: 8.61% [Wait 2]
# Epoch 046 | LR: 5.00e-04 | Train Loss: 0.000170 | Val L2: 8.44% [Wait 3]
# Epoch 047 | LR: 5.00e-04 | Train Loss: 0.000170 | Val L2: 8.49% [Wait 4]
# Epoch 048 | LR: 5.00e-04 | Train Loss: 0.000167 | Val L2: 8.24% <--- save
# Epoch 049 | LR: 5.00e-04 | Train Loss: 0.000157 | Val L2: 8.45% [Wait 1]
# Epoch 050 | LR: 5.00e-04 | Train Loss: 0.000157 | Val L2: 8.37% [Wait 2]
# Epoch 051 | LR: 5.00e-04 | Train Loss: 0.000157 | Val L2: 8.33% [Wait 3]
# Epoch 052 | LR: 5.00e-04 | Train Loss: 0.000150 | Val L2: 8.33% [Wait 4]
# Epoch 053 | LR: 5.00e-04 | Train Loss: 0.000144 | Val L2: 8.34% [Wait 5]
# Epoch 054 | LR: 5.00e-04 | Train Loss: 0.000142 | Val L2: 8.24% <--- save
# Epoch 055 | LR: 5.00e-04 | Train Loss: 0.000142 | Val L2: 8.36% [Wait 1]
# Epoch 056 | LR: 5.00e-04 | Train Loss: 0.000146 | Val L2: 8.19% <--- save
# Epoch 057 | LR: 5.00e-04 | Train Loss: 0.000139 | Val L2: 8.21% [Wait 1]
# Epoch 058 | LR: 5.00e-04 | Train Loss: 0.000132 | Val L2: 8.19% [Wait 2]
# Epoch 059 | LR: 5.00e-04 | Train Loss: 0.000131 | Val L2: 8.39% [Wait 3]
# Epoch 060 | LR: 5.00e-04 | Train Loss: 0.000127 | Val L2: 8.23% [Wait 4]
# Epoch 061 | LR: 5.00e-04 | Train Loss: 0.000126 | Val L2: 8.19% [Wait 5]
# Epoch 062 | LR: 5.00e-04 | Train Loss: 0.000132 | Val L2: 8.32% [Wait 6]
# Epoch 063 | LR: 5.00e-04 | Train Loss: 0.000141 | Val L2: 8.14% <--- save
# Epoch 064 | LR: 5.00e-04 | Train Loss: 0.000135 | Val L2: 8.22% [Wait 1]
# Epoch 065 | LR: 5.00e-04 | Train Loss: 0.000125 | Val L2: 8.31% [Wait 2]
# Epoch 066 | LR: 5.00e-04 | Train Loss: 0.000122 | Val L2: 8.16% [Wait 3]
# Epoch 067 | LR: 5.00e-04 | Train Loss: 0.000116 | Val L2: 8.21% [Wait 4]
# Epoch 068 | LR: 5.00e-04 | Train Loss: 0.000125 | Val L2: 8.16% [Wait 5]
# Epoch 069 | LR: 5.00e-04 | Train Loss: 0.000114 | Val L2: 8.16% [Wait 6]
# Epoch 070 | LR: 5.00e-04 | Train Loss: 0.000116 | Val L2: 8.09% <--- save
# Epoch 071 | LR: 5.00e-04 | Train Loss: 0.000121 | Val L2: 8.22% [Wait 1]
# Epoch 072 | LR: 5.00e-04 | Train Loss: 0.000117 | Val L2: 8.36% [Wait 2]
# Epoch 073 | LR: 5.00e-04 | Train Loss: 0.000116 | Val L2: 8.19% [Wait 3]
# Epoch 074 | LR: 5.00e-04 | Train Loss: 0.000117 | Val L2: 8.19% [Wait 4]
# Epoch 075 | LR: 5.00e-04 | Train Loss: 0.000108 | Val L2: 8.18% [Wait 5]
# Epoch 076 | LR: 5.00e-04 | Train Loss: 0.000106 | Val L2: 8.24% [Wait 6]
# Epoch 077 | LR: 5.00e-04 | Train Loss: 0.000108 | Val L2: 8.22% [Wait 7]
# Epoch 078 | LR: 5.00e-04 | Train Loss: 0.000113 | Val L2: 8.11% [Wait 8]
# Epoch 079 | LR: 5.00e-04 | Train Loss: 0.000106 | Val L2: 8.33% [Wait 9]
# Epoch 080 | LR: 5.00e-04 | Train Loss: 0.000107 | Val L2: 8.14% [Wait 10]
# Epoch 081 | LR: 2.50e-04 | Train Loss: 0.000100 | Val L2: 8.12% [Wait 11]
# Epoch 082 | LR: 2.50e-04 | Train Loss: 0.000078 | Val L2: 7.97% <--- save
# Epoch 083 | LR: 2.50e-04 | Train Loss: 0.000068 | Val L2: 7.98% [Wait 1]
# Epoch 084 | LR: 2.50e-04 | Train Loss: 0.000066 | Val L2: 7.96% <--- save
# Epoch 085 | LR: 2.50e-04 | Train Loss: 0.000065 | Val L2: 7.95% <--- save
# Epoch 086 | LR: 2.50e-04 | Train Loss: 0.000065 | Val L2: 7.96% [Wait 1]
# Epoch 087 | LR: 2.50e-04 | Train Loss: 0.000066 | Val L2: 7.96% [Wait 2]
# Epoch 088 | LR: 2.50e-04 | Train Loss: 0.000066 | Val L2: 7.98% [Wait 3]
# Epoch 089 | LR: 2.50e-04 | Train Loss: 0.000067 | Val L2: 7.98% [Wait 4]
# Epoch 090 | LR: 2.50e-04 | Train Loss: 0.000065 | Val L2: 7.96% [Wait 5]
# Epoch 091 | LR: 2.50e-04 | Train Loss: 0.000065 | Val L2: 7.95% <--- save
# Epoch 092 | LR: 2.50e-04 | Train Loss: 0.000064 | Val L2: 8.02% [Wait 1]
# Epoch 093 | LR: 2.50e-04 | Train Loss: 0.000064 | Val L2: 7.99% [Wait 2]
# Epoch 094 | LR: 2.50e-04 | Train Loss: 0.000063 | Val L2: 7.97% [Wait 3]
# Epoch 095 | LR: 2.50e-04 | Train Loss: 0.000063 | Val L2: 7.99% [Wait 4]
# Epoch 096 | LR: 2.50e-04 | Train Loss: 0.000063 | Val L2: 7.99% [Wait 5]
# Epoch 097 | LR: 2.50e-04 | Train Loss: 0.000062 | Val L2: 7.98% [Wait 6]
# Epoch 098 | LR: 2.50e-04 | Train Loss: 0.000062 | Val L2: 7.97% [Wait 7]
# Epoch 099 | LR: 2.50e-04 | Train Loss: 0.000063 | Val L2: 7.96% [Wait 8]
# Epoch 100 | LR: 2.50e-04 | Train Loss: 0.000063 | Val L2: 7.96% [Wait 9]
# Epoch 101 | LR: 2.50e-04 | Train Loss: 0.000062 | Val L2: 7.97% [Wait 10]
# Epoch 102 | LR: 1.25e-04 | Train Loss: 0.000061 | Val L2: 7.95% [Wait 11]
# Epoch 103 | LR: 1.25e-04 | Train Loss: 0.000054 | Val L2: 7.94% <--- save
# Epoch 104 | LR: 1.25e-04 | Train Loss: 0.000052 | Val L2: 7.93% <--- save
# Epoch 105 | LR: 1.25e-04 | Train Loss: 0.000052 | Val L2: 7.91% <--- save
# Epoch 106 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.93% [Wait 1]
# Epoch 107 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.92% [Wait 2]
# Epoch 108 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.92% [Wait 3]
# Epoch 109 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.93% [Wait 4]
# Epoch 110 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.93% [Wait 5]
# Epoch 111 | LR: 1.25e-04 | Train Loss: 0.000051 | Val L2: 7.92% [Wait 6]
# Epoch 112 | LR: 1.25e-04 | Train Loss: 0.000050 | Val L2: 7.93% [Wait 7]
# Epoch 113 | LR: 1.25e-04 | Train Loss: 0.000050 | Val L2: 7.91% [Wait 8]
# Epoch 114 | LR: 1.25e-04 | Train Loss: 0.000050 | Val L2: 7.92% [Wait 9]
# Epoch 115 | LR: 1.25e-04 | Train Loss: 0.000050 | Val L2: 7.92% [Wait 10]
# Epoch 116 | LR: 6.25e-05 | Train Loss: 0.000049 | Val L2: 7.93% [Wait 11]
# Epoch 117 | LR: 6.25e-05 | Train Loss: 0.000048 | Val L2: 7.91% [Wait 12]
# Epoch 118 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 13]
# Epoch 119 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 14]
# Epoch 120 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 15]
# Epoch 121 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.90% <--- save
# Epoch 122 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.90% [Wait 1]
# Epoch 123 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.90% <--- save
# Epoch 124 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 1]
# Epoch 125 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 2]
# Epoch 126 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 3]
# Epoch 127 | LR: 6.25e-05 | Train Loss: 0.000047 | Val L2: 7.91% [Wait 4]
# Epoch 128 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.91% [Wait 5]
# Epoch 129 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.91% [Wait 6]
# Epoch 130 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.91% [Wait 7]
# Epoch 131 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.91% [Wait 8]
# Epoch 132 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.89% <--- save
# Epoch 133 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.90% [Wait 1]
# Epoch 134 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.90% [Wait 2]
# Epoch 135 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.90% [Wait 3]
# Epoch 136 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.90% [Wait 4]
# Epoch 137 | LR: 6.25e-05 | Train Loss: 0.000046 | Val L2: 7.90% [Wait 5]
# Epoch 138 | LR: 6.25e-05 | Train Loss: 0.000045 | Val L2: 7.90% [Wait 6]
# Epoch 139 | LR: 6.25e-05 | Train Loss: 0.000045 | Val L2: 7.90% [Wait 7]
# Epoch 140 | LR: 6.25e-05 | Train Loss: 0.000045 | Val L2: 7.89% <--- save
# Epoch 141 | LR: 6.25e-05 | Train Loss: 0.000045 | Val L2: 7.90% [Wait 1]
# Epoch 142 | LR: 6.25e-05 | Train Loss: 0.000045 | Val L2: 7.90% [Wait 2]
# Epoch 143 | LR: 3.13e-05 | Train Loss: 0.000045 | Val L2: 7.90% [Wait 3]
# Epoch 144 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.90% [Wait 4]
# Epoch 145 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.89% [Wait 5]
# Epoch 146 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.90% [Wait 6]
# Epoch 147 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.89% [Wait 7]
# Epoch 148 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.90% [Wait 8]
# Epoch 149 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.90% [Wait 9]
# Epoch 150 | LR: 3.13e-05 | Train Loss: 0.000044 | Val L2: 7.90% [Wait 10]
#
# === АНАЛИЗ РЕЗУЛЬТАТОВ НА ТЕСТЕ ===
# Средняя глобальная ошибка на тесте: 7.99%
# Средняя ошибка В СКВАЖИНАХ на тесте: 11.26%

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

train_idx, val_idx, test_idx = get_indices(X_final.shape[0])

train_ds = SpatiotemporalDataset(X_final, train_idx)
val_ds = SpatiotemporalDataset(X_final, val_idx)
test_ds = SpatiotemporalDataset(X_final, test_idx)

BATCH_SIZE = 4

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

MODES_3D = [[12, 24, 24], [12, 16, 16],[12, 16, 16], [12, 24, 24]]
SCALINGS_3D = [[1.0, 0.5, 0.5],[1.0, 0.5, 0.5], [1.0, 2.0, 2.0],[1.0, 2.0, 2.0]]
OUT_CHANNELS_3D =[64, 128, 128, 64] 

base_model = UNO(
    in_channels=2, 
    out_channels=1,
    domain_padding=0.1,
    non_linearity=torch.nn.functional.gelu,
    hidden_channels=64, 
    n_layers=4,
    projection_channels=64,
    uno_out_channels=OUT_CHANNELS_3D,
    uno_n_modes=MODES_3D,
    uno_scalings=SCALINGS_3D,
    channel_mlp_skip="linear"
)

best_model_hybrid = HybridUNO(base_model).to(device)

best_model_hybrid.load_state_dict(torch.load("uno3d_convolution.pth", map_location=device))
best_model_hybrid.eval()

print("Модель загружена")
# Out:
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# fno_skip='linear'
# channel_mlp_skip='linear'
# Модель загружена

# %%
def generate_and_save_gif(model, test_loader, device, static_mask, filename="pressure_1.gif"):
    model.eval()
    
    batch = next(iter(test_loader))
    x_in, y_true = [b.to(device) for b in batch]
    
    mask_3d = static_mask.to(device).float().unsqueeze(0).unsqueeze(0).unsqueeze(0)
    mask_np = static_mask.cpu().numpy()
    
    with torch.no_grad():
        pred = model(x_in)
        pred = pred * mask_3d
        y_true = y_true * mask_3d
    
    t0_true = x_in[0, 0, 0].cpu().numpy()
    future_true = y_true[0, 0].cpu().numpy()
    true_seq = np.concatenate([t0_true[np.newaxis, ...], future_true], axis=0)
    
    future_pred = pred[0, 0].cpu().numpy()
    pred_seq = np.concatenate([t0_true[np.newaxis, ...], future_pred], axis=0)
    
    wells_future = x_in[0, 1].cpu().numpy()
    wells_seq = np.concatenate([wells_future[0:1, ...], wells_future], axis=0)

    T = true_seq.shape[0]
    fig, axes = plt.subplots(1, 4, figsize=(22, 5))
    
    val_min = min(np.min(true_seq), np.min(pred_seq))
    val_max = max(np.max(true_seq), np.max(pred_seq))
    
    cbar_kwargs = {'fraction': 0.046, 'pad': 0.04}
    
    bounds =[0, 1, 3, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 100]
    cmap_error = plt.get_cmap('turbo')
    norm_error = mcolors.BoundaryNorm(bounds, cmap_error.N)
    
    im0 = axes[0].imshow(wells_seq[0], cmap='bwr')
    im1 = axes[1].imshow(true_seq[0], cmap='jet', vmin=val_min, vmax=val_max)
    im2 = axes[2].imshow(pred_seq[0], cmap='jet', vmin=val_min, vmax=val_max)
    im3 = axes[3].imshow(np.zeros_like(true_seq[0]), cmap=cmap_error, norm=norm_error)
    
    axes[0].set_title("Скважины", fontsize=14)
    axes[1].set_title("Истинное давление", fontsize=14)
    axes[2].set_title("Предсказание HybridUNO", fontsize=14)
    axes[3].set_title("Процентная ошибка (%)", fontsize=14)
    
    fig.colorbar(im0, ax=axes[0], **cbar_kwargs)
    fig.colorbar(im1, ax=axes[1], **cbar_kwargs)
    fig.colorbar(im2, ax=axes[2], **cbar_kwargs)
    fig.colorbar(im3, ax=axes[3], boundaries=bounds, ticks=bounds, spacing='uniform', **cbar_kwargs)
    
    for ax in axes: 
        ax.set_xticks([])
        ax.set_yticks([])
        for spine in ax.spines.values():
            spine.set_edgecolor('black')
            
    time_text = fig.suptitle("Инициализация...", fontsize=16, fontweight='bold')

    def update(frame):
        im0.set_array(wells_seq[frame])
        im1.set_array(true_seq[frame])
        im2.set_array(pred_seq[frame])
        
        true_frame = true_seq[frame]
        pred_frame = pred_seq[frame]
        
        masked_true = true_frame[mask_np > 0]
        max_true_val = np.max(np.abs(masked_true)) if len(masked_true) > 0 and np.max(np.abs(masked_true)) > 1e-8 else 1.0
        
        rel_err_map = np.zeros_like(true_frame)
        rel_err_map[mask_np > 0] = np.clip((np.abs(true_frame - pred_frame)[mask_np > 0] / max_true_val) * 100, 0, 100)
        im3.set_array(rel_err_map)
        
        diff_n = np.linalg.norm((pred_frame - true_frame) * mask_np)
        true_n = np.linalg.norm(true_frame * mask_np)
        frame_err = (diff_n / (true_n + 1e-8)) * 100
        
        step_lbl = "Начальное условие" if frame == 0 else f"Шаг {frame}/{T-1}"
        time_text.set_text(f"Время: {step_lbl}  |  Глобальная L2 Ошибка: {frame_err:.2f}%")
        
        return[im0, im1, im2, im3, time_text]

    ani = animation.FuncAnimation(fig, update, frames=T, interval=250, blit=False)
    ani.save(filename, writer='pillow', fps=4)
    plt.close(fig)
    print(f"Анимация успешно сохранена как '{filename}'.")

generate_and_save_gif(
    model=best_model_hybrid, 
    test_loader=test_loader, 
    device=device, 
    static_mask=STATIC_MASK, 
    filename="trajectory_evaluate.gif"
)
# Out:
# Анимация успешно сохранена как 'trajectory_evaluate.gif'.
