# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.animation as animation
import xarray as xr

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from neuralop.models.local_no import LocalNO
from neuralop.models import UNO
from neuralop.layers.spectral_convolution import SpectralConv

from tabulate import tabulate

torch.serialization.add_safe_globals([torch.nn.functional.gelu])

# %%
class ContinuousBasisConv3d(nn.Module):
    def __init__(self, channels, radii=[1, 2, 3], num_bases=12, h=1.0, is_differential=False, basis_type='rbf'):
        super().__init__()
        self.channels = channels
        self.radii = radii
        self.num_bases = num_bases
        self.h = h
        self.is_differential = is_differential
        self.basis_type = basis_type 
        
        max_r = max(radii)
        self.padding = (0, max_r, max_r) 

        grid_t, grid_y, grid_x = torch.meshgrid(
            torch.arange(0, 1),
            torch.arange(-max_r, max_r + 1),
            torch.arange(-max_r, max_r + 1),
            indexing='ij'
        )
        self.register_buffer('grid_t', grid_t.float())
        self.register_buffer('grid_y', grid_y.float())
        self.register_buffer('grid_x', grid_x.float())

        self.time_scale = nn.Parameter(torch.tensor(1.0))
        
        init_p =[]
        for i in range(num_bases):
            init_p.append(radii[i % len(radii)])
            
        self.basis_params = nn.Parameter(torch.tensor(init_p, dtype=torch.float32))
        
        fan_in = channels * (1 * (2*max_r+1) * (2*max_r+1))
        std = (2.0 / fan_in) ** 0.5
        self.basis_weights = nn.Parameter(torch.randn(channels, channels, num_bases) * std)

    def generate_kernel(self):
        dx = self.grid_x * self.h
        dy = self.grid_y * self.h
        dt = self.grid_t * self.time_scale
        r_sq = dt**2 + dx**2 + dy**2
        r = torch.sqrt(r_sq + 1e-8)
    
        params = torch.clamp(torch.abs(self.basis_params), min=0.1)
        p = params.view(-1, 1, 1, 1)
    
        half = self.num_bases // 2
        
        if self.basis_type == 'rbf':
            base_1 = torch.exp(-(r_sq.unsqueeze(0) / (p[:half]**2)))
        elif self.basis_type == 'wendland':
            r_norm = r.unsqueeze(0) / p[:half]
            relu_part = F.relu(1.0 - r_norm)
            base_1 = (relu_part ** 4) * (4 * r_norm + 1.0)
            
        base_2 = F.relu(1.0 - (r.unsqueeze(0) / p[half:]))
        
        bases_tensor = torch.cat([base_1, base_2], dim=0)
        kernel = torch.einsum('oib, btyx -> oityx', self.basis_weights, bases_tensor)
        kernel = kernel / np.sqrt(self.num_bases)
        
        if self.is_differential:
            kernel_mean = kernel.mean(dim=(2, 3, 4), keepdim=True)
            kernel = kernel - kernel_mean
            kernel = kernel / (self.h + 1e-8)
            
        return kernel

    def forward(self, x):
        weight = self.generate_kernel()
        
        if weight.shape[2] == 1:
            B, C, T, Y, X = x.shape
            
            weight_2d = weight.squeeze(2)
            
            x_2d = x.permute(0, 2, 1, 3, 4).reshape(B * T, C, Y, X)
            
            pad_y, pad_x = self.padding[1], self.padding[2]
            out_2d = F.conv2d(x_2d, weight_2d, bias=None, padding=(pad_y, pad_x))
            
            out = out_2d.reshape(B, T, self.channels, Y, X).permute(0, 2, 1, 3, 4)
            return out
        else:
            return F.conv3d(x, weight, bias=None, padding=self.padding)

# %%
class TrueLocalNOBlock3d(nn.Module):
    def __init__(self, channels, modes, radii=[1, 2, 3, 5], num_bases=12, basis_type='rbf'):
        super().__init__()
        self.fno_conv = SpectralConv(in_channels=channels, out_channels=channels, n_modes=modes)
        
        self.local_integral = ContinuousBasisConv3d(
            channels, 
            radii=radii, 
            num_bases=num_bases, 
            is_differential=False,
            basis_type=basis_type
        )
        
        self.local_differential = ContinuousBasisConv3d(
            channels, 
            radii=radii, 
            num_bases=num_bases, 
            is_differential=True, 
            basis_type=basis_type
        )
        
        self.skip = nn.Conv3d(channels, channels, kernel_size=1)
        self.norm = nn.InstanceNorm3d(channels)
        self.activation = nn.GELU()
        self.fusion_weights = nn.Parameter(torch.ones(4)) 

    def forward(self, x, mask=None):
        identity = x 
        w = torch.softmax(self.fusion_weights, dim=0)
        
        out_fno = self.fno_conv(x)
        out_int = self.local_integral(x)
        out_diff = self.local_differential(x)
        out_skip = self.skip(x)
        
        out = (w[0] * out_fno + w[1] * out_int + w[2] * out_diff + w[3] * out_skip)
        out = self.norm(identity + out)
        
        if mask is not None:
            out = out * mask
        return self.activation(out)


class CustomLocalNO3d(nn.Module):
    def __init__(self, 
                 in_channels=2, 
                 out_channels=1, 
                 hidden_channels=32,
                 n_layers=4, 
                 modes=(10, 20, 20), 
                 radii=[1, 2, 3, 5], 
                 num_bases=12, 
                 basis_type='rbf'
    ):
        super().__init__()
        self.lift = nn.Conv3d(in_channels, hidden_channels, kernel_size=1)
        
        self.blocks = nn.ModuleList([
            TrueLocalNOBlock3d(channels=hidden_channels, 
                               modes=modes, 
                               radii=radii, 
                               num_bases=num_bases, 
                               basis_type=basis_type
            ) for _ in range(n_layers)]
        )
        
        self.project = nn.Sequential(
            nn.Conv3d(hidden_channels, hidden_channels, kernel_size=1),
            nn.GELU(),
            nn.Conv3d(hidden_channels, out_channels, kernel_size=1)
        )

    def forward(self, x, mask=None):
        x = self.lift(x)
        if mask is not None: x = x * mask
        for block in self.blocks:
            x = block(x, mask=mask)
        x = self.project(x)
        return x

# %%
CURRENT_DIRECTORY = f'horizontal_correct/'
DATA_PATH = f'data'
ASSETS_PATH = f'assets'
MODELS_PATH = f'models'

filepaths =[f'{DATA_PATH}/source_{i}.hdf5' for i in range(1, 4)]

dim_map = {
    'phony_dim_0' : 'time',
    'phony_dim_1' : 'sample',
    'phony_dim_2' : 'channel',
    'phony_dim_3' : 'Y',
    'phony_dim_4' : 'X'
}

# %%
def preprocess(path):
    print(f'Открытие датасета : {path}')
    ds = xr.open_dataset(path, engine='h5netcdf', phony_dims='sort').rename(dim_map)
    pressure = ds.dataset.isel(channel=0)
    source = ds.source
    return xr.Dataset({'pressure': pressure, 'source':source}, attrs=ds.attrs)

print("Загрузка данных...")
processed_datasets = [preprocess(f) for f in filepaths]
final_ds = xr.concat(processed_datasets, dim='sample').squeeze('phony_dim_5')
# Out:
# Загрузка данных...
# Открытие датасета : data/source_1.hdf5
# Открытие датасета : data/source_2.hdf5
# Открытие датасета : data/source_3.hdf5

# %%
raw_p = final_ds.pressure.values
mask_2d = ~np.isnan(raw_p[0, 0])

p_min, p_max = np.nanmin(raw_p), np.nanmax(raw_p)
norm_p = np.zeros_like(raw_p, dtype='float32')
norm_p[:, :, mask_2d] = (raw_p[:, :, mask_2d] - p_min) / (p_max - p_min)

s_raw = final_ds.source.values.copy()
s_raw[..., ~mask_2d] = 0 
s_abs_max = np.max(np.abs(s_raw))
norm_s = (s_raw / s_abs_max).astype('float32') if s_abs_max != 0 else s_raw

# %%
P_tensor = torch.from_numpy(norm_p).permute(1, 0, 2, 3).float()
S_tensor = torch.from_numpy(norm_s).float()
X_final = torch.stack([P_tensor, S_tensor], dim=2)
STATIC_MASK = torch.from_numpy(mask_2d.astype('float32'))

# %%
def get_indices(size, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    np.random.seed(2318)
    indices = np.arange(size)
    np.random.shuffle(indices)
    train_end = int(size * train_ratio)
    val_end = train_end + int(size * val_ratio)
    return indices[:train_end], indices[train_end:val_end], indices[val_end:]

# %%
class SpatiotemporalDataset(Dataset):
    def __init__(self, data, indices):
        self.data = data[indices] 
        self.N_samples = self.data.shape[0]
        self.T_total = self.data.shape[1]
        self.T_future = self.T_total - 1

    def __len__(self):
        return self.N_samples

    def __getitem__(self, idx):
        p_init = self.data[idx, 0, 0] 
        p_init_cube = p_init.unsqueeze(0).repeat(self.T_future, 1, 1)
        s_future_cube = self.data[idx, 1:, 1]
        x = torch.stack([p_init_cube, s_future_cube], dim=0)
        y = self.data[idx, 1:, 0].unsqueeze(0)
        return x, y

# %%
def train_model(modes,
                hidden_channels, 
                n_layers, 
                train_loader, 
                val_loader, 
                device, 
                static_mask, 
                epochs=200, 
                well_penalty=10.0, 
                radii=[1, 2, 3, 5], 
                num_bases=12, 
                basis_type='rbf'
    ):
    torch.backends.cudnn.benchmark = True 
    
    model = CustomLocalNO3d(
        in_channels=2, 
        out_channels=1, 
        hidden_channels=hidden_channels, 
        n_layers=n_layers,
        modes=modes,
        radii=radii,
        num_bases=num_bases, 
        basis_type=basis_type
    ).to(device)

    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-3) 
    
    mask = static_mask.to(device).float()
    mask_3d = mask.unsqueeze(0).unsqueeze(0).unsqueeze(0) 

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15)
    
    best_val_l2 = float('inf')
    best_model_path = f"SFNO_3D_{basis_type}_b{num_bases}_best.pth" 
    patience_counter = 0

    print(f"=== TRAINING: {basis_type.upper()} | Radii: {radii} | Bases: {num_bases} | Penalty: {well_penalty}x ===")

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0.0

        for batch in train_loader:
            x_in, y_true =[b.to(device) for b in batch]
            optimizer.zero_grad()
            
            pred = model(x_in, mask=mask_3d) 
            
            wells_cube = x_in[:, 1:2] 
            well_mask = (torch.abs(wells_cube) > 1e-5).float()
            weight_map = torch.ones_like(pred) + (well_mask * (well_penalty - 1.0))
            
            error = (pred - y_true) * mask_3d
            loss = ((error ** 2) * weight_map).mean()
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            total_train_loss += loss.item() * x_in.size(0)
            
        epoch_train_loss = total_train_loss / len(train_loader.dataset)

        model.eval()
        val_l2_errors =[]
        with torch.no_grad():
            for batch_v in val_loader:
                x_v, y_v =[b.to(device) for b in batch_v]
                pred_v = model(x_v, mask=mask_3d) 
                
                pred_v = pred_v * mask_3d
                true_v = y_v * mask_3d
                
                diff_norm = torch.norm((pred_v - true_v).reshape(x_v.size(0), -1), p=2, dim=1).float()
                true_norm = torch.norm(true_v.reshape(x_v.size(0), -1), p=2, dim=1).float()
                rel_l2 = (diff_norm / torch.clamp(true_norm, min=1e-8)) * 100
                val_l2_errors.extend(rel_l2.cpu().numpy())

        epoch_mean = np.mean(val_l2_errors)
        scheduler.step(epoch_mean) 
        
        current_lr = optimizer.param_groups[0]['lr']
        if epoch_mean < best_val_l2:
            best_val_l2 = epoch_mean
            torch.save(model.state_dict(), best_model_path)
            status = "<--- save"
            patience_counter = 0
        else:
            status = f"[Wait {patience_counter+1}]"
            patience_counter += 1
            
        print(f"Epoch {epoch+1:03d} | LR: {current_lr:.2e} | Train Loss: {epoch_train_loss:.6f} | Val L2: {epoch_mean:.2f}% {status}")

        if patience_counter >= 30:
            print("=== EARLY STOPPING ===")
            break

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    return model

# %%
GPU_ID = "cuda:2"
BASIS_TYPE = 'rbf' # 'rbf' / 'wendland'
NUM_BASES = 12
RADII = [1, 2, 3]
WELL_PENALTY = 10.0

MODES_3D = (10, 16, 16)
HIDDEN_CHANNELS = 32
N_LAYERS = 4
EPOCHS = 200
BATCH_SIZE = 2

device = GPU_ID if torch.cuda.is_available() else "cpu"

train_idx, val_idx, test_idx = get_indices(X_final.shape[0])


train_ds = SpatiotemporalDataset(X_final, train_idx)
val_ds = SpatiotemporalDataset(X_final, val_idx)
test_ds = SpatiotemporalDataset(X_final, test_idx)


train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

best_model = train_model(
    modes=MODES_3D, 
    hidden_channels=HIDDEN_CHANNELS, 
    n_layers=N_LAYERS,
    train_loader=train_loader, 
    val_loader=val_loader,
    static_mask=STATIC_MASK,
    device=device, 
    epochs=EPOCHS,
    well_penalty=WELL_PENALTY,
    radii=RADII,
    num_bases=NUM_BASES,
    basis_type=BASIS_TYPE
)
# Out:
# === TRAINING: RBF | Radii: [1, 2, 3] | Bases: 12 | Penalty: 10.0x ===
# Epoch 001 | LR: 5.00e-04 | Train Loss: 0.008315 | Val L2: 23.24% <--- save
# Epoch 002 | LR: 5.00e-04 | Train Loss: 0.004257 | Val L2: 19.55% <--- save
# Epoch 003 | LR: 5.00e-04 | Train Loss: 0.003277 | Val L2: 16.89% <--- save
# Epoch 004 | LR: 5.00e-04 | Train Loss: 0.002814 | Val L2: 16.58% <--- save
# Epoch 005 | LR: 5.00e-04 | Train Loss: 0.002499 | Val L2: 15.65% <--- save
# Epoch 006 | LR: 5.00e-04 | Train Loss: 0.002310 | Val L2: 14.87% <--- save
# Epoch 007 | LR: 5.00e-04 | Train Loss: 0.002158 | Val L2: 14.43% <--- save
# Epoch 008 | LR: 5.00e-04 | Train Loss: 0.002004 | Val L2: 14.81% [Wait 1]
# Epoch 009 | LR: 5.00e-04 | Train Loss: 0.001852 | Val L2: 13.62% <--- save
# Epoch 010 | LR: 5.00e-04 | Train Loss: 0.001718 | Val L2: 13.99% [Wait 1]
# Epoch 011 | LR: 5.00e-04 | Train Loss: 0.001576 | Val L2: 12.24% <--- save
# Epoch 012 | LR: 5.00e-04 | Train Loss: 0.001467 | Val L2: 11.97% <--- save
# Epoch 013 | LR: 5.00e-04 | Train Loss: 0.001372 | Val L2: 12.22% [Wait 1]
# Epoch 014 | LR: 5.00e-04 | Train Loss: 0.001263 | Val L2: 11.33% <--- save
# Epoch 015 | LR: 5.00e-04 | Train Loss: 0.001199 | Val L2: 12.05% [Wait 1]
# Epoch 016 | LR: 5.00e-04 | Train Loss: 0.001137 | Val L2: 10.91% <--- save
# Epoch 017 | LR: 5.00e-04 | Train Loss: 0.001076 | Val L2: 10.46% <--- save
# Epoch 018 | LR: 5.00e-04 | Train Loss: 0.001019 | Val L2: 10.25% <--- save
# Epoch 019 | LR: 5.00e-04 | Train Loss: 0.000997 | Val L2: 10.75% [Wait 1]
# Epoch 020 | LR: 5.00e-04 | Train Loss: 0.000930 | Val L2: 10.76% [Wait 2]
# Epoch 021 | LR: 5.00e-04 | Train Loss: 0.000894 | Val L2: 10.18% <--- save
# Epoch 022 | LR: 5.00e-04 | Train Loss: 0.000863 | Val L2: 10.21% [Wait 1]
# Epoch 023 | LR: 5.00e-04 | Train Loss: 0.000832 | Val L2: 9.97% <--- save
# Epoch 024 | LR: 5.00e-04 | Train Loss: 0.000809 | Val L2: 10.12% [Wait 1]
# Epoch 025 | LR: 5.00e-04 | Train Loss: 0.000774 | Val L2: 9.84% <--- save
# Epoch 026 | LR: 5.00e-04 | Train Loss: 0.000748 | Val L2: 9.83% <--- save
# Epoch 027 | LR: 5.00e-04 | Train Loss: 0.000735 | Val L2: 9.45% <--- save
# Epoch 028 | LR: 5.00e-04 | Train Loss: 0.000700 | Val L2: 9.78% [Wait 1]
# Epoch 029 | LR: 5.00e-04 | Train Loss: 0.000688 | Val L2: 9.39% <--- save
# Epoch 030 | LR: 5.00e-04 | Train Loss: 0.000667 | Val L2: 9.73% [Wait 1]
# Epoch 031 | LR: 5.00e-04 | Train Loss: 0.000644 | Val L2: 9.39% [Wait 2]
# Epoch 032 | LR: 5.00e-04 | Train Loss: 0.000632 | Val L2: 9.66% [Wait 3]
# Epoch 033 | LR: 5.00e-04 | Train Loss: 0.000603 | Val L2: 9.47% [Wait 4]
# Epoch 034 | LR: 5.00e-04 | Train Loss: 0.000592 | Val L2: 9.11% <--- save
# Epoch 035 | LR: 5.00e-04 | Train Loss: 0.000579 | Val L2: 9.16% [Wait 1]
# Epoch 036 | LR: 5.00e-04 | Train Loss: 0.000553 | Val L2: 9.13% [Wait 2]
# Epoch 037 | LR: 5.00e-04 | Train Loss: 0.000548 | Val L2: 9.04% <--- save
# Epoch 038 | LR: 5.00e-04 | Train Loss: 0.000532 | Val L2: 9.01% <--- save
# Epoch 039 | LR: 5.00e-04 | Train Loss: 0.000522 | Val L2: 9.23% [Wait 1]
# Epoch 040 | LR: 5.00e-04 | Train Loss: 0.000507 | Val L2: 9.02% [Wait 2]
# Epoch 041 | LR: 5.00e-04 | Train Loss: 0.000493 | Val L2: 8.96% <--- save
# Epoch 042 | LR: 5.00e-04 | Train Loss: 0.000479 | Val L2: 8.95% <--- save
# Epoch 043 | LR: 5.00e-04 | Train Loss: 0.000472 | Val L2: 9.38% [Wait 1]
# Epoch 044 | LR: 5.00e-04 | Train Loss: 0.000458 | Val L2: 9.43% [Wait 2]
# Epoch 045 | LR: 5.00e-04 | Train Loss: 0.000454 | Val L2: 8.94% <--- save
# Epoch 046 | LR: 5.00e-04 | Train Loss: 0.000436 | Val L2: 8.78% <--- save
# Epoch 047 | LR: 5.00e-04 | Train Loss: 0.000431 | Val L2: 9.49% [Wait 1]
# Epoch 048 | LR: 5.00e-04 | Train Loss: 0.000422 | Val L2: 8.71% <--- save
# Epoch 049 | LR: 5.00e-04 | Train Loss: 0.000410 | Val L2: 8.77% [Wait 1]
# Epoch 050 | LR: 5.00e-04 | Train Loss: 0.000400 | Val L2: 8.70% <--- save
# Epoch 051 | LR: 5.00e-04 | Train Loss: 0.000393 | Val L2: 8.60% <--- save
# Epoch 052 | LR: 5.00e-04 | Train Loss: 0.000390 | Val L2: 8.71% [Wait 1]
# Epoch 053 | LR: 5.00e-04 | Train Loss: 0.000381 | Val L2: 8.54% <--- save
# Epoch 054 | LR: 5.00e-04 | Train Loss: 0.000368 | Val L2: 8.93% [Wait 1]
# Epoch 055 | LR: 5.00e-04 | Train Loss: 0.000366 | Val L2: 8.71% [Wait 2]
# Epoch 056 | LR: 5.00e-04 | Train Loss: 0.000361 | Val L2: 8.86% [Wait 3]
# Epoch 057 | LR: 5.00e-04 | Train Loss: 0.000352 | Val L2: 9.15% [Wait 4]
# Epoch 058 | LR: 5.00e-04 | Train Loss: 0.000344 | Val L2: 8.66% [Wait 5]
# Epoch 059 | LR: 5.00e-04 | Train Loss: 0.000346 | Val L2: 8.58% [Wait 6]
# Epoch 060 | LR: 5.00e-04 | Train Loss: 0.000332 | Val L2: 8.53% <--- save
# Epoch 061 | LR: 5.00e-04 | Train Loss: 0.000324 | Val L2: 8.64% [Wait 1]
# Epoch 062 | LR: 5.00e-04 | Train Loss: 0.000328 | Val L2: 8.72% [Wait 2]
# Epoch 063 | LR: 5.00e-04 | Train Loss: 0.000317 | Val L2: 8.68% [Wait 3]
# Epoch 064 | LR: 5.00e-04 | Train Loss: 0.000317 | Val L2: 8.64% [Wait 4]
# Epoch 065 | LR: 5.00e-04 | Train Loss: 0.000307 | Val L2: 8.56% [Wait 5]
# Epoch 066 | LR: 5.00e-04 | Train Loss: 0.000308 | Val L2: 8.42% <--- save
# Epoch 067 | LR: 5.00e-04 | Train Loss: 0.000294 | Val L2: 8.45% [Wait 1]
# Epoch 068 | LR: 5.00e-04 | Train Loss: 0.000291 | Val L2: 8.53% [Wait 2]
# Epoch 069 | LR: 5.00e-04 | Train Loss: 0.000292 | Val L2: 8.64% [Wait 3]
# Epoch 070 | LR: 5.00e-04 | Train Loss: 0.000289 | Val L2: 8.53% [Wait 4]
# Epoch 071 | LR: 5.00e-04 | Train Loss: 0.000281 | Val L2: 8.48% [Wait 5]
# Epoch 072 | LR: 5.00e-04 | Train Loss: 0.000271 | Val L2: 8.48% [Wait 6]
# Epoch 073 | LR: 5.00e-04 | Train Loss: 0.000274 | Val L2: 8.41% <--- save
# Epoch 074 | LR: 5.00e-04 | Train Loss: 0.000267 | Val L2: 8.32% <--- save
# Epoch 075 | LR: 5.00e-04 | Train Loss: 0.000265 | Val L2: 8.31% <--- save
# Epoch 076 | LR: 5.00e-04 | Train Loss: 0.000263 | Val L2: 8.31% <--- save
# Epoch 077 | LR: 5.00e-04 | Train Loss: 0.000257 | Val L2: 8.36% [Wait 1]
# Epoch 078 | LR: 5.00e-04 | Train Loss: 0.000255 | Val L2: 8.30% <--- save
# Epoch 079 | LR: 5.00e-04 | Train Loss: 0.000251 | Val L2: 8.63% [Wait 1]
# Epoch 080 | LR: 5.00e-04 | Train Loss: 0.000248 | Val L2: 8.62% [Wait 2]
# Epoch 081 | LR: 5.00e-04 | Train Loss: 0.000247 | Val L2: 8.50% [Wait 3]
# Epoch 082 | LR: 5.00e-04 | Train Loss: 0.000242 | Val L2: 8.35% [Wait 4]
# Epoch 083 | LR: 5.00e-04 | Train Loss: 0.000243 | Val L2: 8.37% [Wait 5]
# Epoch 084 | LR: 5.00e-04 | Train Loss: 0.000241 | Val L2: 8.43% [Wait 6]
# Epoch 085 | LR: 5.00e-04 | Train Loss: 0.000235 | Val L2: 8.35% [Wait 7]
# Epoch 086 | LR: 5.00e-04 | Train Loss: 0.000232 | Val L2: 8.22% <--- save
# Epoch 087 | LR: 5.00e-04 | Train Loss: 0.000230 | Val L2: 8.29% [Wait 1]
# Epoch 088 | LR: 5.00e-04 | Train Loss: 0.000229 | Val L2: 8.19% <--- save
# Epoch 089 | LR: 5.00e-04 | Train Loss: 0.000227 | Val L2: 8.29% [Wait 1]
# Epoch 090 | LR: 5.00e-04 | Train Loss: 0.000224 | Val L2: 8.23% [Wait 2]
# Epoch 091 | LR: 5.00e-04 | Train Loss: 0.000219 | Val L2: 8.36% [Wait 3]
# Epoch 092 | LR: 5.00e-04 | Train Loss: 0.000217 | Val L2: 8.20% [Wait 4]
# Epoch 093 | LR: 5.00e-04 | Train Loss: 0.000221 | Val L2: 8.28% [Wait 5]
# Epoch 094 | LR: 5.00e-04 | Train Loss: 0.000212 | Val L2: 8.30% [Wait 6]
# Epoch 095 | LR: 5.00e-04 | Train Loss: 0.000210 | Val L2: 8.34% [Wait 7]
# Epoch 096 | LR: 5.00e-04 | Train Loss: 0.000211 | Val L2: 8.21% [Wait 8]
# Epoch 097 | LR: 5.00e-04 | Train Loss: 0.000212 | Val L2: 8.29% [Wait 9]
# Epoch 098 | LR: 5.00e-04 | Train Loss: 0.000207 | Val L2: 8.24% [Wait 10]
# Epoch 099 | LR: 5.00e-04 | Train Loss: 0.000207 | Val L2: 8.22% [Wait 11]
# Epoch 100 | LR: 5.00e-04 | Train Loss: 0.000209 | Val L2: 8.31% [Wait 12]
# Epoch 101 | LR: 5.00e-04 | Train Loss: 0.000201 | Val L2: 8.17% <--- save
# Epoch 102 | LR: 5.00e-04 | Train Loss: 0.000198 | Val L2: 8.13% <--- save
# Epoch 103 | LR: 5.00e-04 | Train Loss: 0.000197 | Val L2: 8.16% [Wait 1]
# Epoch 104 | LR: 5.00e-04 | Train Loss: 0.000198 | Val L2: 8.10% <--- save
# Epoch 105 | LR: 5.00e-04 | Train Loss: 0.000196 | Val L2: 8.27% [Wait 1]
# Epoch 106 | LR: 5.00e-04 | Train Loss: 0.000190 | Val L2: 8.11% [Wait 2]
# Epoch 107 | LR: 5.00e-04 | Train Loss: 0.000194 | Val L2: 8.23% [Wait 3]
# Epoch 108 | LR: 5.00e-04 | Train Loss: 0.000192 | Val L2: 8.07% <--- save
# Epoch 109 | LR: 5.00e-04 | Train Loss: 0.000192 | Val L2: 8.13% [Wait 1]
# Epoch 110 | LR: 5.00e-04 | Train Loss: 0.000188 | Val L2: 8.13% [Wait 2]
# Epoch 111 | LR: 5.00e-04 | Train Loss: 0.000186 | Val L2: 8.20% [Wait 3]
# Epoch 112 | LR: 5.00e-04 | Train Loss: 0.000182 | Val L2: 8.04% <--- save
# Epoch 113 | LR: 5.00e-04 | Train Loss: 0.000181 | Val L2: 8.18% [Wait 1]
# Epoch 114 | LR: 5.00e-04 | Train Loss: 0.000181 | Val L2: 8.08% [Wait 2]
# Epoch 115 | LR: 5.00e-04 | Train Loss: 0.000179 | Val L2: 8.16% [Wait 3]
# Epoch 116 | LR: 5.00e-04 | Train Loss: 0.000180 | Val L2: 8.12% [Wait 4]
# Epoch 117 | LR: 5.00e-04 | Train Loss: 0.000182 | Val L2: 8.02% <--- save
# Epoch 118 | LR: 5.00e-04 | Train Loss: 0.000176 | Val L2: 8.06% [Wait 1]
# Epoch 119 | LR: 5.00e-04 | Train Loss: 0.000174 | Val L2: 8.72% [Wait 2]
# Epoch 120 | LR: 5.00e-04 | Train Loss: 0.000173 | Val L2: 8.05% [Wait 3]
# Epoch 121 | LR: 5.00e-04 | Train Loss: 0.000177 | Val L2: 8.00% <--- save
# Epoch 122 | LR: 5.00e-04 | Train Loss: 0.000172 | Val L2: 8.10% [Wait 1]
# Epoch 123 | LR: 5.00e-04 | Train Loss: 0.000170 | Val L2: 8.05% [Wait 2]
# Epoch 124 | LR: 5.00e-04 | Train Loss: 0.000169 | Val L2: 8.31% [Wait 3]
# Epoch 125 | LR: 5.00e-04 | Train Loss: 0.000169 | Val L2: 7.99% <--- save
# Epoch 126 | LR: 5.00e-04 | Train Loss: 0.000167 | Val L2: 8.04% [Wait 1]
# Epoch 127 | LR: 5.00e-04 | Train Loss: 0.000167 | Val L2: 8.02% [Wait 2]
# Epoch 128 | LR: 5.00e-04 | Train Loss: 0.000165 | Val L2: 8.00% [Wait 3]
# Epoch 129 | LR: 5.00e-04 | Train Loss: 0.000164 | Val L2: 8.03% [Wait 4]
# Epoch 130 | LR: 5.00e-04 | Train Loss: 0.000162 | Val L2: 8.04% [Wait 5]
# Epoch 131 | LR: 5.00e-04 | Train Loss: 0.000168 | Val L2: 8.22% [Wait 6]
# Epoch 132 | LR: 5.00e-04 | Train Loss: 0.000161 | Val L2: 8.03% [Wait 7]
# Epoch 133 | LR: 5.00e-04 | Train Loss: 0.000159 | Val L2: 8.04% [Wait 8]
# Epoch 134 | LR: 5.00e-04 | Train Loss: 0.000161 | Val L2: 8.04% [Wait 9]
# Epoch 135 | LR: 5.00e-04 | Train Loss: 0.000162 | Val L2: 8.11% [Wait 10]
# Epoch 136 | LR: 5.00e-04 | Train Loss: 0.000162 | Val L2: 8.02% [Wait 11]
# Epoch 137 | LR: 5.00e-04 | Train Loss: 0.000160 | Val L2: 8.09% [Wait 12]
# Epoch 138 | LR: 5.00e-04 | Train Loss: 0.000154 | Val L2: 8.07% [Wait 13]
# Epoch 139 | LR: 5.00e-04 | Train Loss: 0.000155 | Val L2: 8.05% [Wait 14]
# Epoch 140 | LR: 5.00e-04 | Train Loss: 0.000154 | Val L2: 8.01% [Wait 15]
# Epoch 141 | LR: 2.50e-04 | Train Loss: 0.000157 | Val L2: 8.00% [Wait 16]
# Epoch 142 | LR: 2.50e-04 | Train Loss: 0.000130 | Val L2: 7.86% <--- save
# Epoch 143 | LR: 2.50e-04 | Train Loss: 0.000121 | Val L2: 7.86% [Wait 1]
# Epoch 144 | LR: 2.50e-04 | Train Loss: 0.000121 | Val L2: 7.85% <--- save
# Epoch 145 | LR: 2.50e-04 | Train Loss: 0.000121 | Val L2: 7.83% <--- save
# Epoch 146 | LR: 2.50e-04 | Train Loss: 0.000121 | Val L2: 7.84% [Wait 1]
# Epoch 147 | LR: 2.50e-04 | Train Loss: 0.000120 | Val L2: 7.86% [Wait 2]
# Epoch 148 | LR: 2.50e-04 | Train Loss: 0.000119 | Val L2: 7.85% [Wait 3]
# Epoch 149 | LR: 2.50e-04 | Train Loss: 0.000119 | Val L2: 7.90% [Wait 4]
# Epoch 150 | LR: 2.50e-04 | Train Loss: 0.000118 | Val L2: 7.87% [Wait 5]
# Epoch 151 | LR: 2.50e-04 | Train Loss: 0.000118 | Val L2: 7.89% [Wait 6]
# Epoch 152 | LR: 2.50e-04 | Train Loss: 0.000117 | Val L2: 7.86% [Wait 7]
# Epoch 153 | LR: 2.50e-04 | Train Loss: 0.000116 | Val L2: 7.86% [Wait 8]
# Epoch 154 | LR: 2.50e-04 | Train Loss: 0.000116 | Val L2: 7.86% [Wait 9]
# Epoch 155 | LR: 2.50e-04 | Train Loss: 0.000115 | Val L2: 7.86% [Wait 10]
# Epoch 156 | LR: 2.50e-04 | Train Loss: 0.000114 | Val L2: 7.85% [Wait 11]
# Epoch 157 | LR: 2.50e-04 | Train Loss: 0.000115 | Val L2: 7.84% [Wait 12]
# Epoch 158 | LR: 2.50e-04 | Train Loss: 0.000114 | Val L2: 7.85% [Wait 13]
# Epoch 159 | LR: 2.50e-04 | Train Loss: 0.000114 | Val L2: 7.86% [Wait 14]
# Epoch 160 | LR: 2.50e-04 | Train Loss: 0.000113 | Val L2: 7.85% [Wait 15]
# Epoch 161 | LR: 2.50e-04 | Train Loss: 0.000112 | Val L2: 7.82% <--- save
# Epoch 162 | LR: 2.50e-04 | Train Loss: 0.000112 | Val L2: 7.83% [Wait 1]
# Epoch 163 | LR: 2.50e-04 | Train Loss: 0.000112 | Val L2: 7.83% [Wait 2]
# Epoch 164 | LR: 2.50e-04 | Train Loss: 0.000112 | Val L2: 7.88% [Wait 3]
# Epoch 165 | LR: 2.50e-04 | Train Loss: 0.000111 | Val L2: 7.91% [Wait 4]
# Epoch 166 | LR: 2.50e-04 | Train Loss: 0.000111 | Val L2: 7.81% <--- save
# Epoch 167 | LR: 2.50e-04 | Train Loss: 0.000111 | Val L2: 7.83% [Wait 1]
# Epoch 168 | LR: 2.50e-04 | Train Loss: 0.000110 | Val L2: 7.87% [Wait 2]
# Epoch 169 | LR: 2.50e-04 | Train Loss: 0.000110 | Val L2: 7.85% [Wait 3]
# Epoch 170 | LR: 2.50e-04 | Train Loss: 0.000109 | Val L2: 7.86% [Wait 4]
# Epoch 171 | LR: 2.50e-04 | Train Loss: 0.000109 | Val L2: 7.85% [Wait 5]
# Epoch 172 | LR: 2.50e-04 | Train Loss: 0.000109 | Val L2: 7.82% [Wait 6]
# Epoch 173 | LR: 2.50e-04 | Train Loss: 0.000108 | Val L2: 7.84% [Wait 7]
# Epoch 174 | LR: 2.50e-04 | Train Loss: 0.000107 | Val L2: 7.81% [Wait 8]
# Epoch 175 | LR: 2.50e-04 | Train Loss: 0.000108 | Val L2: 7.83% [Wait 9]
# Epoch 176 | LR: 2.50e-04 | Train Loss: 0.000107 | Val L2: 7.80% <--- save
# Epoch 177 | LR: 2.50e-04 | Train Loss: 0.000107 | Val L2: 7.81% [Wait 1]
# Epoch 178 | LR: 2.50e-04 | Train Loss: 0.000107 | Val L2: 7.84% [Wait 2]
# Epoch 179 | LR: 2.50e-04 | Train Loss: 0.000106 | Val L2: 7.84% [Wait 3]
# Epoch 180 | LR: 2.50e-04 | Train Loss: 0.000105 | Val L2: 7.80% <--- save
# Epoch 181 | LR: 2.50e-04 | Train Loss: 0.000105 | Val L2: 7.82% [Wait 1]
# Epoch 182 | LR: 2.50e-04 | Train Loss: 0.000105 | Val L2: 7.87% [Wait 2]
# Epoch 183 | LR: 2.50e-04 | Train Loss: 0.000105 | Val L2: 7.80% [Wait 3]
# Epoch 184 | LR: 2.50e-04 | Train Loss: 0.000104 | Val L2: 7.89% [Wait 4]
# Epoch 185 | LR: 2.50e-04 | Train Loss: 0.000104 | Val L2: 7.88% [Wait 5]
# Epoch 186 | LR: 2.50e-04 | Train Loss: 0.000104 | Val L2: 7.82% [Wait 6]
# Epoch 187 | LR: 2.50e-04 | Train Loss: 0.000102 | Val L2: 7.83% [Wait 7]
# Epoch 188 | LR: 2.50e-04 | Train Loss: 0.000103 | Val L2: 7.82% [Wait 8]
# Epoch 189 | LR: 2.50e-04 | Train Loss: 0.000103 | Val L2: 7.81% [Wait 9]
# Epoch 190 | LR: 2.50e-04 | Train Loss: 0.000102 | Val L2: 7.81% [Wait 10]
# Epoch 191 | LR: 2.50e-04 | Train Loss: 0.000102 | Val L2: 7.89% [Wait 11]
# Epoch 192 | LR: 2.50e-04 | Train Loss: 0.000101 | Val L2: 7.81% [Wait 12]
# Epoch 193 | LR: 2.50e-04 | Train Loss: 0.000102 | Val L2: 7.79% <--- save
# Epoch 194 | LR: 2.50e-04 | Train Loss: 0.000102 | Val L2: 7.84% [Wait 1]
# Epoch 195 | LR: 2.50e-04 | Train Loss: 0.000100 | Val L2: 7.83% [Wait 2]
# Epoch 196 | LR: 2.50e-04 | Train Loss: 0.000100 | Val L2: 7.85% [Wait 3]
# Epoch 197 | LR: 2.50e-04 | Train Loss: 0.000101 | Val L2: 7.82% [Wait 4]
# Epoch 198 | LR: 2.50e-04 | Train Loss: 0.000101 | Val L2: 7.86% [Wait 5]
# Epoch 199 | LR: 2.50e-04 | Train Loss: 0.000100 | Val L2: 7.83% [Wait 6]
# Epoch 200 | LR: 2.50e-04 | Train Loss: 0.000101 | Val L2: 7.81% [Wait 7]
#
# ════════════════════════════════════════════════════════════════════════════════
#  ФИЗИЧЕСКИЕ ПАРАМЕТРЫ МОДЕЛИ
# ════════════════════════════════════════════════════════════════════════════════
#
# ТАБЛИЦА 1: Распределение внимания сети (Fusion Weights)
# Показывает, какую ветку сеть считает самой важной на каждом этапе.
# ╒════════╤════════════════╤═══════════════════════╤═════════════════════════╤═══════════════════╕
# │ Блок   │ FNO (Глобал)   │ Интеграл (Диффузия)   │ Дифференциал (Потоки)   │ Skip (Residual)   │
# ╞════════╪════════════════╪═══════════════════════╪═════════════════════════╪═══════════════════╡
# │ Слой 1 │ 45.53%         │ 9.85%                 │ 19.25%                  │ 25.38%            │
# ├────────┼────────────────┼───────────────────────┼─────────────────────────┼───────────────────┤
# │ Слой 2 │ 53.59%         │ 12.19%                │ 23.71%                  │ 10.52%            │
# ├────────┼────────────────┼───────────────────────┼─────────────────────────┼───────────────────┤
# │ Слой 3 │ 76.30%         │ 6.54%                 │ 14.53%                  │ 2.63%             │
# ├────────┼────────────────┼───────────────────────┼─────────────────────────┼───────────────────┤
# │ Слой 4 │ 75.19%         │ 6.49%                 │ 16.51%                  │ 1.81%             │
# ╘════════╧════════════════╧═══════════════════════╧═════════════════════════╧═══════════════════╛
#
#
# ТАБЛИЦА 2: Интегральное ядро
# ╒════════╤══════════════╤══════════════════════════════════════════════════════════════════════════╤══════════════════════════════════╤══════════════════════════╕
# │ Блок   │   Time Scale │ Выученные Радиусы базисов (p)                                            │ Мин / Макс вес (Cancellation?)   │   Средняя амплитуда веса │
# ╞════════╪══════════════╪══════════════════════════════════════════════════════════════════════════╪══════════════════════════════════╪══════════════════════════╡
# │ Слой 1 │        0.907 │ [0.28, 1.39, 2.45, 0.26, 1.49, 2.5 , 0.92, 1.41, 2.25, 0.91, 1.41, 2.25] │ [-1.55 ... 1.29]                 │                   0.1356 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 2 │        0.907 │ [0.26, 1.62, 2.88, 0.29, 1.74, 2.83, 0.91, 1.53, 2.49, 0.9 , 1.41, 2.46] │ [-2.66 ... 1.58]                 │                   0.1469 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 3 │        0.907 │ [0.26, 1.22, 2.62, 0.3 , 1.17, 2.56, 0.95, 1.41, 2.2 , 0.95, 1.41, 2.22] │ [-1.91 ... 1.25]                 │                   0.1261 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 4 │        0.907 │ [0.24, 0.49, 2.48, 0.24, 0.3 , 2.5 , 0.99, 1.41, 2.22, 0.99, 1.41, 2.24] │ [-2.99 ... 0.95]                 │                   0.1154 │
# ╘════════╧══════════════╧══════════════════════════════════════════════════════════════════════════╧══════════════════════════════════╧══════════════════════════╛
#
#
# ТАБЛИЦА 3: Дифференциальное ядро
# ╒════════╤══════════════╤══════════════════════════════════════════════════════════════════════════╤══════════════════════════════════╤══════════════════════════╕
# │ Блок   │   Time Scale │ Выученные Радиусы базисов (p)                                            │ Мин / Макс вес (Cancellation?)   │   Средняя амплитуда веса │
# ╞════════╪══════════════╪══════════════════════════════════════════════════════════════════════════╪══════════════════════════════════╪══════════════════════════╡
# │ Слой 1 │        0.907 │ [0.72, 0.97, 3.54, 0.84, 0.99, 3.49, 0.95, 2.  , 2.24, 0.95, 2.  , 2.  ] │ [-0.90 ... 1.21]                 │                   0.1432 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 2 │        0.907 │ [0.85, 1.75, 3.34, 0.86, 1.73, 3.33, 0.98, 2.  , 3.16, 0.99, 2.  , 3.16] │ [-2.01 ... 1.54]                 │                   0.1682 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 3 │        0.907 │ [0.79, 3.15, 3.54, 0.79, 3.35, 3.55, 0.99, 2.  , 3.16, 0.99, 2.  , 3.16] │ [-3.91 ... 1.53]                 │                   0.1767 │
# ├────────┼──────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────┼──────────────────────────┤
# │ Слой 4 │        0.907 │ [0.23, 4.23, 4.33, 0.23, 3.62, 4.31, 0.99, 2.01, 3.16, 0.99, 1.96, 3.16] │ [-4.30 ... 4.62]                 │                   0.1632 │
# ╘════════╧══════════════╧══════════════════════════════════════════════════════════════════════════╧══════════════════════════════════╧══════════════════════════╛
#
#
# Residual учитывается слабо (на первом слое 25.38%) сеть больше доверяет вычисленной физике (FNO/Ядрам).
# ════════════════════════════════════════════════════════════════════════════════
#
# ============================================================
#  ВИЗУАЛИЗАЦИЯ ВЕСОВ
# ============================================================
# === АНАЛИЗ РЕЗУЛЬТАТОВ НА ТЕСТЕ ===
# Средняя глобальная ошибка на тесте: 8.17%
# Средняя ошибка В СКВАЖИНАХ на тесте: 11.23%
#
# === ГЕНЕРАЦИЯ GIF: SFNO_3D_rbf_b12.gif ===
# Гифка сохранена как 'SFNO_3D_rbf_b12.gif'.

# %%
def visualize_layer_activations_grid(model, test_loader, device, num_samples=3, save_dir="."):
    model.eval()
    activations = {}

    def get_activation(name):
        def hook(model, input, output):
            activations[name] = output.detach().cpu()
        return hook

    last_block_idx = len(model.blocks) - 1
    target_block = model.blocks[last_block_idx]
    
    handle_fno = target_block.fno_conv.register_forward_hook(get_activation('fno'))
    handle_int = target_block.local_integral.register_forward_hook(get_activation('integral'))
    handle_diff = target_block.local_differential.register_forward_hook(get_activation('differential'))
    handle_skip = target_block.skip.register_forward_hook(get_activation('skip'))

    batch = next(iter(test_loader))
    x_in, y_true =[b.to(device) for b in batch]
    
    with torch.no_grad():
        _ = model(x_in)
        
    handle_fno.remove()
    handle_int.remove()
    handle_diff.remove()
    handle_skip.remove()

    act_fno = activations['fno']
    act_int = activations['integral']     
    act_diff = activations['differential']
    act_skip = activations['skip']
    
    wells = x_in[:, 1].cpu()              
    true_pressure = y_true[:, 0].cpu()
    
    fw = torch.softmax(target_block.fusion_weights.detach(), dim=0).cpu().numpy()
    weight_fno = fw[0]
    weight_int = fw[1]  
    weight_diff = fw[2] 
    weight_skip = fw[3]
    
    actual_samples = min(num_samples, x_in.shape[0])
    t_mid = act_int.shape[2] // 2
    cbar_kwargs = {'fraction': 0.046, 'pad': 0.04}
    
    os.makedirs(save_dir, exist_ok=True)

    for i in range(actual_samples):
        fig, axes = plt.subplots(1, 5, figsize=(26, 5.5))
        
        map_fno = torch.mean(torch.abs(act_fno[i, :, t_mid, :, :]), dim=0).numpy() * weight_fno
        map_int = torch.mean(torch.abs(act_int[i, :, t_mid, :, :]), dim=0).numpy() * weight_int
        map_diff = torch.mean(torch.abs(act_diff[i, :, t_mid, :, :]), dim=0).numpy() * weight_diff
        map_skip = torch.mean(torch.abs(act_skip[i, :, t_mid, :, :]), dim=0).numpy() * weight_skip
        
        wells_np = np.abs(wells[i, t_mid].numpy())
        well_y, well_x = np.where(wells_np > 1e-5)
        true_p_np = true_pressure[i, t_mid].numpy()

        vmax_fno = np.percentile(map_fno, 99) if np.max(map_fno) > 1e-8 else 1.0
        vmax_int = np.percentile(map_int, 99) if np.max(map_int) > 1e-8 else 1.0
        vmax_diff = np.percentile(map_diff, 99) if np.max(map_diff) > 1e-8 else 1.0
        vmax_skip = np.percentile(map_skip, 99) if np.max(map_skip) > 1e-8 else 1.0

        marker_opts = dict(color='white', marker='+', s=80, linewidths=1.5, alpha=0.8)

        im0 = axes[0].imshow(true_p_np, cmap='jet', origin='lower')
        axes[0].set_title(f"Истинное давление", fontsize=15, fontweight='bold', pad=10)
        fig.colorbar(im0, ax=axes[0], **cbar_kwargs)

        im1 = axes[1].imshow(map_fno, cmap='plasma', origin='lower', vmax=vmax_fno)
        axes[1].scatter(well_x, well_y, **marker_opts)
        axes[1].set_title(f"FNO (Глобальный)\nВес: {weight_fno*100:.1f}%", fontsize=15, fontweight='bold', pad=10)
        fig.colorbar(im1, ax=axes[1], **cbar_kwargs)

        im2 = axes[2].imshow(map_int, cmap='plasma', origin='lower', vmax=vmax_int)
        axes[2].scatter(well_x, well_y, **marker_opts)
        axes[2].set_title(f"Интеграл (Диффузия)\nВес: {weight_int*100:.1f}%", fontsize=15, fontweight='bold', pad=10)
        fig.colorbar(im2, ax=axes[2], **cbar_kwargs)

        im3 = axes[3].imshow(map_diff, cmap='plasma', origin='lower', vmax=vmax_diff)
        axes[3].scatter(well_x, well_y, **marker_opts)
        axes[3].set_title(f"Дифференциал (Потоки)\nВес: {weight_diff*100:.1f}%", fontsize=15, fontweight='bold', pad=10)
        fig.colorbar(im3, ax=axes[3], **cbar_kwargs)
        
        im4 = axes[4].imshow(map_skip, cmap='plasma', origin='lower', vmax=vmax_skip)
        axes[4].scatter(well_x, well_y, **marker_opts)
        axes[4].set_title(f"Skip Connection\nВес: {weight_skip*100:.1f}%", fontsize=15, fontweight='bold', pad=10)
        fig.colorbar(im4, ax=axes[4], **cbar_kwargs)

        for ax in axes:
            ax.set_xticks([])
            ax.set_yticks([])

        plt.tight_layout()
        
        save_path = os.path.join(save_dir, f"AttentionMap_s{i+1}_b12_m16_h32.png")
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"График сэмпла {i+1} сохранен: {save_path}")

    plt.show()
    

visualize_layer_activations_grid(model, test_loader, device)
# Out:
# ================================================================================
# 🔬 АНАЛИЗ ВНИМАНИЯ СЕТИ (ВСЕ 4 ВЕТКИ С УЧЕТОМ ВЕСОВ)
# ================================================================================
# График сэмпла 1 сохранен: ./AttentionMap_s1_b12_m16_h32.png
# График сэмпла 2 сохранен: ./AttentionMap_s2_b12_m16_h32.png
